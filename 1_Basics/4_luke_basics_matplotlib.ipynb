# %%
# !pip install -qq -U datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
df = dataset['train'].to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
import pandas as pd

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.8.1
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.1
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.1.0
# ...

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0,5,0.1)
y = np.sin(x)

plt.plot(x,y)

# %%
# plot job postings by month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
jobs_by_month = df.groupby(by = ['job_posted_month']).size().sort_index()

# %%
type(jobs_by_month)
# Out:
# pandas.core.series.Series

# %%
jobs_df = pd.DataFrame({'month':jobs_by_month.index, 'job_postings':jobs_by_month.values})

# %%
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         12 non-null     int32
#  1   job_postings  12 non-null     int64
# dtypes: int32(1), int64(1)
# memory usage: 276.0 bytes

# %%
plt.plot(jobs_df.month, jobs_df.job_postings)

# %%
plt.bar(jobs_df.month, jobs_df.job_postings)
# Out:
# <BarContainer object of 12 artists>

# %%
months = ['January', 'February', 'March', 'April']
postings = [120, 150, 100, 130]

# %%
plt.plot(months,postings)
plt.show()

# %%
job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']
postings = [50, 75, 60]

plt.bar(job_titles, postings)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_month.value_counts().sort_values(by = 'job_posted_month')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-36-2555323919.py in <cell line: 0>()
# ----> 1 df.job_posted_month.value_counts().sort_values('job_posted_month')
#
# TypeError: Series.sort_values() takes 1 positional argument but 2 were given

# %%
date_counts = df.job_posted_date.dt.date.value_counts().sort_index()

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-01    3603
# 2023-01-02    2772
# 2023-01-03    2565
# 2023-01-04    3937
# 2023-01-05    3297
#               ...
# 2023-12-27    1834
# 2023-12-28    1767
# 2023-12-29    1107
# 2023-12-30     897
# 2023-12-31     758
# Name: count, Length: 365, dtype: int64

# %%
type(date_counts)
# Out:
# pandas.core.series.Series

# %%
date_counts.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 365 entries, 2023-01-01 to 2023-12-31
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 365 non-null    int64
# dtypes: int64(1)
# memory usage: 13.8+ KB

# %%
date_counts_df = pd.DataFrame({'posted_date': date_counts.index, 'job_postings':date_counts.values})

# %%
date_counts_df
# Out:
#     posted_date  job_postings
# 0    2023-01-01          3603
# 1    2023-01-02          2772
# 2    2023-01-03          2565
# 3    2023-01-04          3937
# 4    2023-01-05          3297
# ..          ...           ...
# 360  2023-12-27          1834
# 361  2023-12-28          1767
# 362  2023-12-29          1107
# 363  2023-12-30           897
# 364  2023-12-31           758
#
# [365 rows x 2 columns]

# %%
plt.plot(date_counts_df.posted_date, date_counts_df.job_postings)

# %% [markdown]
# # panda series
#
# One dimensional
#
# Indexed
#
# Diverse Data types

# %%
x = pd.Series([10,20,30,40], index = ["a", "b", "c", "d"])

# %%
x
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
x.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
x.values
# Out:
# array([10, 20, 30, 40])

# %%
jobs = df.job_title_short.value_counts().sort_values(ascending=True)

# %%
jobs
# Out:
# job_title_short
# Cloud Engineer                12331
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Scientist         36957
# Senior Data Engineer          44563
# Software Engineer             44929
# Business Analyst              49063
# Data Scientist               172286
# Data Engineer                186241
# Data Analyst                 196075
# Name: count, dtype: int64

# %%
plt.bar(jobs.index, jobs.values)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(jobs.index, jobs.values)
# Out:
# <BarContainer object of 10 artists>

# %%
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# jobs by country

jobs_country = df.job_country.value_counts().head(5)

# %%
plt.bar(jobs_country.index, jobs_country.values, color = 'orange')
# Out:
# <BarContainer object of 5 artists>

# %%
avg_salary = df.groupby(by = 'job_title_short')['salary_year_avg'].mean()

# %%
avg_salary
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
type(avg_salary)
# Out:
# pandas.core.series.Series

# %%
avg_salary.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10 entries, Business Analyst to Software Engineer
# Series name: salary_year_avg
# Non-Null Count  Dtype
# --------------  -----
# 10 non-null     float64
# dtypes: float64(1)
# memory usage: 460.0+ bytes

# %%
plt.barh(avg_salary.index, avg_salary.values)
# Out:
# <BarContainer object of 10 artists>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.job_posted_month.mean()
# Out:
# np.float64(6.305538338969202)

# %%
avg_monthly_salary = df.groupby(by = ['job_posted_month'])['salary_year_avg'].mean().sort_index()

# %%
plt.plot(avg_monthly_salary.index, avg_monthly_salary.values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
job_counts = df.job_title_short.value_counts()

# %%
plt.bar(job_counts.index, job_counts.values)
plt.title("Postings by Job Title",color = 'green')
plt.show()

# %%
plt.bar(job_counts.index, job_counts.values)
plt.title("Postings by Job Title",color = 'green')
plt.ylabel("count of jobs")
plt.xlabel("job title")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.bar(job_counts.index, job_counts.values)
plt.title("Postings by Job Title",color = 'green')
plt.ylabel("count of jobs")
plt.xlabel("job title")
# plt.xticks(rotation = 90)
plt.xticks(rotation = 45) # by default it is center aligned
plt.show()

# %%
plt.bar(job_counts.index, job_counts.values)
plt.title("Postings by Job Title",color = 'green')
plt.ylabel("count of jobs")
plt.xlabel("job title")
# plt.xticks(rotation = 90)
plt.xticks(rotation = 45, ha = 'right') # horzontal alignment
plt.show()

# %%
jobs_by_country = df.job_country.value_counts().head(10)

# %%
jobs_by_country
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Name: count, dtype: int64

# %%
plt.bar(jobs_by_country.index, jobs_by_country.values)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(jobs_by_country.index, jobs_by_country.values)
plt.xlabel('Country')
plt.ylabel('Number of Postings')
plt.title('Number of Jobs per Country')
plt.xticks(rotation = 45, ha = 'right')
plt.show()

# %%
avg_title_salary = df.groupby(by = ['job_title_short'])['salary_year_avg'].mean().sort_values()

# %%
avg_title_salary
# Out:
# job_title_short
# Business Analyst              91082.612833
# Data Analyst                  93841.907854
# Cloud Engineer               111268.453846
# Software Engineer            113393.760054
# Senior Data Analyst          113911.363665
# Machine Learning Engineer    126774.315972
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Name: salary_year_avg, dtype: float64

# %%
plt.barh(avg_title_salary.index, avg_title_salary.values)
plt.xlabel('Average Salary')
plt.title('Average Salary by Job Title')
plt.show()

# %%
avg_six_month_salary = df.groupby(by = ['job_posted_month'])['salary_year_avg'].mean().sort_index()

# %%
plt.plot(avg_six_month_salary.index, avg_six_month_salary.values, color = 'red', label='Average Salary')
plt.xlabel('Month')
plt.ylabel('Average Salary')
plt.title('Average Salary by Job Month')
plt.legend()

plt.show()

# %%
job_counts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
job_counts.plot()
# Out:
# <Axes: xlabel='job_title_short'>

# %%
job_counts.plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_title_short'>

# %%
job_counts.plot(kind = 'bar')
plt.title("Postings by Job Title",color = 'green')
plt.ylabel("count of jobs")
plt.xlabel("job title")
# plt.xticks(rotation = 90)
plt.xticks(rotation = 45, ha = 'right') # horzontal alignment
plt.show()

# %%
df.plot(x = 'job_posted_date', y = 'salary_year_avg', kind = 'line')
# Out:
# <Axes: xlabel='job_posted_date'>

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_via.head()
# Out:
# 0       via Work Nearby
# 1      via BeBee México
# 2          via LinkedIn
# 3     via Diversity.com
# 4    via Clearance Jobs
# Name: job_via, dtype: object

# %%
x = df.job_via.value_counts().sort_values(ascending = False).head(5)

# %%
x.plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_via'>

# %%
y = df.job_location.value_counts().sort_values(ascending = False).head(5)

# %%
y
# Out:
# job_location
# Anywhere                       69552
# Singapore                      23415
# Paris, France                  12311
# Bengaluru, Karnataka, India    11474
# London, UK                     10564
# Name: count, dtype: int64

# %%
y.plot(kind = 'barh')
plt.xlabel('Count of Jobs')
plt.ylabel('Job Location')
plt.title('Number of Job Postings by Job Location')
# Out:
# Text(0.5, 1.0, 'Number of Job Postings by Job Location')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_month_name'] = df['job_posted_date'].dt.to_period('M')
monthly_job_counts = df['job_posted_month_name'].value_counts().sort_index()
monthly_job_counts.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.title('Trend of Job Postings Over Time')
plt.show()

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df['job_posted_month_name'].value_counts().sort_index()
# Out:
# job_posted_month_name
# 2023-01    91822
# 2023-02    64578
# 2023-03    64084
# 2023-04    62919
# 2023-05    52104
# 2023-06    61572
# 2023-07    63777
# 2023-08    75162
# 2023-09    62359
# 2023-10    66611
# 2023-11    64450
# 2023-12    56303
# Freq: M, Name: count, dtype: int64

# %%
med_salary = df.groupby(by = ['job_title_short'])['salary_year_avg'].median().sort_values()

# %%
med_salary.plot(kind = 'barh')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df['salary_year_avg'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
