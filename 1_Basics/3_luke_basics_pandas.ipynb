# %%
df.job_title_short.unique() # returns an array of unique values
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
# !pip install -qq -U datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# ...

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
# !pip list # list out different libraries available
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.8.1
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.1
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.1.0
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
 import numpy as np

# %%
 np.mean(df['total_bedrooms'])
# Out:
# np.float64(529.9506666666666)

# %%
df['total_bedrooms'].mean()
# Out:
# np.float64(529.9506666666666)

# %%
df.total_bedrooms
# dot notation, can only be used for existing columns. Cannot be used to create new columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-105-1431068141.py in <cell line: 0>()
# ----> 1 df.total_bedrooms
#       2 # dot notation, can only be used for existing columns. Cannot be used to create new columns
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'total_bedrooms'

# %%
df['total_bedrooms']
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df.total_bedrooms[0]
# Out:
# np.float64(661.0)

# %%
df['total_bedrooms'][0]
# Out:
# np.float64(661.0)

# %%
df['total_bedrooms'][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-22-3300371802.py in <cell line: 0>()
# ----> 1 df['total_bedrooms'][-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
df.total_bedrooms[len(df)-1]
# Out:
# np.float64(263.0)

# %%
df.total_bedrooms[2999]
# Out:
# np.float64(263.0)

# %%
dataset = load_dataset('lukebarousse/data_jobs')

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#     num_rows: 785741
# })

# %%
dataset['train'].to_pandas()
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df = dataset['train'].to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.tail() # outputs last 5 rows automatically
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
df.tail(10)
# Out:
#              job_title_short  \
# 785731         Data Engineer
# 785732         Data Engineer
# 785733     Software Engineer
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785733                                    DevOps Engineer
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_location
# Out:
# 0                               Watertown, CT
# 1                Guadalajara, Jalisco, Mexico
# 2                             Berlin, Germany
# 3                             San Antonio, TX
# 4                              Washington, DC
#                          ...
# 785736                              Singapura
# 785737                     Bad Rodach, Jerman
# 785738                               Malaysia
# 785739    Newark, New Jersey, Amerika Serikat
# 785740                                  India
# Name: job_location, Length: 785741, dtype: object

# %%
df["job_location"]
# Out:
# 0                               Watertown, CT
# 1                Guadalajara, Jalisco, Mexico
# 2                             Berlin, Germany
# 3                             San Antonio, TX
# 4                              Washington, DC
#                          ...
# 785736                              Singapura
# 785737                     Bad Rodach, Jerman
# 785738                               Malaysia
# 785739    Newark, New Jersey, Amerika Serikat
# 785740                                  India
# Name: job_location, Length: 785741, dtype: object

# %%
df.search_location
# Out:
# 0         Texas, United States
# 1                       Mexico
# 2                      Germany
# 3         Texas, United States
# 4                        Sudan
#                   ...
# 785736               Singapore
# 785737                 Germany
# 785738                Malaysia
# 785739                   Sudan
# 785740                   India
# Name: search_location, Length: 785741, dtype: object

# %%
df.job_title[56]
# Out:
# 'Principal Statistical Scientist'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.head() # top 5 rows
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df.job_country.head()
# Out:
# 0    United States
# 1           Mexico
# 2          Germany
# 3    United States
# 4            Sudan
# Name: job_country, dtype: object

# %%
df['job_title','job_location'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('job_title', 'job_location')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-44-3550467693.py in <cell line: 0>()
# ----> 1 df['job_title','job_location'].head()
#
# ...

# %%
df[['job_title','job_location']].head()
# dont forget that you have to provide a list with brackets inside the index with brackets
# so 2 pairs of brackets when referencing multiple columns
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
df[['job_title']].head()
# Out:
#                                            job_title
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs

# %%
df['job_title'].head()
# Out:
# 0    Senior Clinical Data Engineer / Principal Clin...
# 1                                         Data Analyst
# 2    Data Engineer/Scientist/Analyst, Mid or Senior...
# 3    LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                               Data Engineer- Sr Jobs
# Name: job_title, dtype: object

# %%
type(df[['job_title']].head()) # returns a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['job_title'].head()) # returns a series
# Out:
# pandas.core.series.Series

# %% [markdown]
# # iloc

# %%
# integer location

# %%
df.job_country[2]
# Out:
# 'Germany'

# %%
type(df.job_country[2])
# Out:
# str

# %%
df.iloc[2] # row 2
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# ...

# %%
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[90] # row 90
# Out:
# job_title_short                                             Data Scientist
# job_title                                                   Data Scientist
# job_location                                                     Australia
# job_via                                                via BeBee Australia
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                  Australia
# job_posted_date                                        2023-11-25 13:12:03
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                      Australia
# salary_rate                                                           None
# ...

# %%
df.iloc[90:100] # rows 91 to 100
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# ...

# %%
df.iloc[90:100, 0:2] # 91 to 100 rows for first two coloumns

# df.iloc[rows, columns]
# Out:
#          job_title_short                                          job_title
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe() # only gives statistics of numerical values
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.job_title_short.unique() # returns an array of unique values
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[df.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df.job_title[df.job_title_short == 'Data Analyst'].unique()
# Out:
# array(['Data Analyst', 'Stagiaire Data Analyst (H/F) - Lyon (69006)',
#        'Stage - Data Analyst F/H', ...,
#        'Data Analyst Senior - Full-time / Part-time',
#        'Data Analyst - CRYPTOGRAPHY - Full-time',
#        'Amul Careers 2023 - Apply Online - Data Analysis Post'],
#       dtype=object)

# %%
df[df.job_title_short == 'Data Analyst' and df.salary_year_avg > 100_000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-82-3317842310.py in <cell line: 0>()
# ----> 1 df[df.job_title_short == 'Data Analyst' and df.salary_hour_avg > 100_000]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 100_000)]
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# ...

# %%
df.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
# ...

# %%
df[df.job_schedule_type == 'Full-time'].head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
# 2               False               Germany  2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df[df.job_skills.isna()]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 21            Data Scientist
# 26             Data Engineer
# 29            Data Scientist
# 36              Data Analyst
# ...                      ...
# 785713        Cloud Engineer
# 785715          Data Analyst
# 785718      Business Analyst
# 785724         Data Engineer
# 785729         Data Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 21      Stage - data scientist – génération ia de donn...
# 26                                          Data Engineer
# 29                                         Data Scientist
# 36                                           Data Analyst
# ...                                                   ...
# 785713  Data Center Chief Engineer, AWS Infrastructure...
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785718                      Senior Performance QA Analyst
# ...

# %%
df[df.job_skills.notna()]
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %% [markdown]
# # cleaning

# %%
df.job_posted_date[0]
# Out:
# '2023-06-16 13:44:15'

# %%
type(df.job_posted_date[0])
# Out:
# str

# %% [markdown]
# **Datetime**

# %%
# convert to date time

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month # its a property not a method, so you dont need to provide ()
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# **sorting**

# %%
df.sort_values(by = df['job_posted_date']) # you are referencing the column, not the column name. Use column name in sort_values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-110-2107388317.py in <cell line: 0>()
# ----> 1 df.sort_values(by = df['job_posted_date']) # you are referencing the column, not the column name. Use column name in sort_values
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
# ...

# %%
df.sort_values(by = 'job_posted_date') # does not change original df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.sort_values(by = 'job_posted_date', inplace = True) # changes the original df and sorts

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
# droping columns and rows

# %%
df.drop(labels = 'salary_hour_avg', axis = 1)
# axis = 1 drops columns
# axis = 0 drops rows
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.drop(labels = 'salary_hour_avg', axis = 1, inplace = True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.dropna(subset = ['salary_year_avg'])
# drops rows where salary_year_avg is NaN
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
df.dropna(subset = ['salary_year_avg'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
df.sort_values(by='salary_year_avg', ascending=False).head(10)
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
# 404932          Data Engineer
# 554140         Data Scientist
# 417241  Senior Data Scientist
# 618461  Senior Data Scientist
# 124265         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
# 404932               Hybrid - Data Engineer - Up to $600k
# 554140          Staff Data Scientist - Business Analytics
# 417241                              Senior Data Scientist
# 618461                         VP Data Science & Research
# ...

# %%
df.job_work_from_home
# Out:
# 108883    False
# 334082    False
# 365786     True
# 366073    False
# 108099    False
#           ...
# 186163    False
# 421728    False
# 313161    False
# 336301    False
# 327439    False
# Name: job_work_from_home, Length: 22003, dtype: bool

# %%
df["is_remote"] = df['job_work_from_home']

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
df.drop(labels = ['is_remote'], axis = 1, inplace = True)

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
df[df['job_work_from_home'] == True]
# Out:
#              job_title_short                       job_title job_location  \
# 365786      Business Analyst  Hospitality Operations Analyst     Anywhere
# 69156         Data Scientist            Staff Data Scientist     Anywhere
# 2862          Data Scientist        Marketing Data Scientist     Anywhere
# 377062         Data Engineer                   Data Engineer     Anywhere
# 207828         Data Engineer            Data Engineer - Web3     Anywhere
# ...                      ...                             ...          ...
# 250599          Data Analyst  Supply Chain Analytics Manager     Anywhere
# 120858          Data Analyst   Machine Learning Data Analyst     Anywhere
# 581356  Senior Data Engineer            Senior Data Engineer     Anywhere
# 652503        Data Scientist     Remote Data Science Manager     Anywhere
# 24616         Data Scientist    Digital Analytics Consultant     Anywhere
#
#                                    job_via job_schedule_type  \
# ...

# %%
# prompt: Create a new column is_remote that indicates whether the job is remote (True) or not (False) based on the job_work_from_home column

df['is_remote'] = df['job_work_from_home']

# %%
df['is_office'] = (df['job_work_from_home'] == False)

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
df['job_posted_year'] = df.job_posted_date.dt.year

# %%
df.head()
# Out:
#          job_title_short                       job_title    job_location  \
# 108883    Data Scientist                  Data Scientist   Calabasas, CA
# 334082     Data Engineer                   Data Engineer       Argentina
# 365786  Business Analyst  Hospitality Operations Analyst        Anywhere
# 366073      Data Analyst     Data Analytics Professional     Atlanta, GA
# 108099    Data Scientist    Lead Data Scientist (Hybrid)  Burnsville, MN
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 334082                        via EchoJobs         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
# 366073                   via CareerBuilder         Full-time
# 108099                     via Recruit.net         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# ...

# %%
df = dataset['train'].to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.dropna(subset = ['salary_year_avg'], axis = 0).head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# # Analysis

# %%
df = dataset['train'].to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg  \
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738
#
#        job_posted_month
# count     785741.000000
# mean           6.305538
# min            1.000000
# 25%            3.000000
# 50%            6.000000
# 75%            9.000000
# max           12.000000
# std            3.525408

# %%
df.count() # count of non null values in each column
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# job_posted_month         785741
# dtype: int64

# %%
df.salary_year_avg.median() # median value
# Out:
# 115000.0

# %%
df.salary_year_avg.min()
# Out:
# 15000.0

# %%
#index of min

df.salary_year_avg.idxmin()
# Out:
# 665729

# %%
df.iloc[df.salary_year_avg.idxmin()]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df.iloc[df.salary_year_avg.idxmax()]
# Out:
# job_title_short                                           Data Scientist
# job_title                                                 Data Scientist
# job_location                                                 Madison, SD
# job_via                                    via Cooperative Career Center
# job_schedule_type                                              Full-time
# job_work_from_home                                                 False
# search_location                                  Illinois, United States
# job_posted_date                                      2023-05-04 19:06:06
# job_no_degree_mention                                              False
# job_health_insurance                                                True
# job_country                                                United States
# salary_rate                                                         year
# salary_year_avg                                                 960000.0
# ...

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df.job_title_short.values
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer', ...,
#        'Business Analyst', 'Data Engineer', 'Software Engineer'],
#       dtype=object)

# %%
df.job_title_short.value_counts() # count of each unique value
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
# what is the minimum salary of each of the job titles

# df.groupby(by = [columns to group])[columns to aggregate].aggregate_function()

df.groupby(by = ['job_title_short'])['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
# multiple groupby columns
df.groupby(by = ['job_title_short', 'job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
# multiple columns to aggregate
df.groupby(by = ['job_title_short'])[['salary_year_avg', 'salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
# multiple aggreagtions

df.groupby(by = ['job_title_short'])[['salary_year_avg', 'salary_hour_avg']].agg(['median', 'min', 'max'])
# Out:
#                           salary_year_avg                    salary_hour_avg  \
#                                    median      min       max          median
# job_title_short
# Business Analyst                  85000.0  16500.0  387460.0       40.362499
# Cloud Engineer                    90000.0  42000.0  280000.0       40.000000
# Data Analyst                      90000.0  25000.0  650000.0       32.615002
# Data Engineer                    125000.0  15000.0  525000.0       58.500000
# Data Scientist                   127500.0  27000.0  960000.0       47.500000
# Machine Learning Engineer        106415.0  30000.0  325000.0       47.535000
# Senior Data Analyst              111175.0  30000.0  425000.0       47.500000
# Senior Data Engineer             147500.0  35000.0  425000.0       61.500000
# Senior Data Scientist            155500.0  45000.0  890000.0       47.620003
# Software Engineer                 99150.0  28000.0  375000.0       47.560001
#
#
# ...

# %%
df = dataset['train'].to_pandas()

# %%
# what are the countries for which the job is posted for

df.job_country.value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Lesotho                3
# Mauritania             3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
# which countries are top 10 in job postings
df.job_country.value_counts().head(10)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Name: count, dtype: int64

# %%
#isin method
df.job_country.isin(["United States"])
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
# any country has India in the job country?
df.job_country.isin(["India"]).any()
# Out:
# np.True_

# %%
# any country has North Korea in the job country?
df.job_country.isin(["North Korea"]).any()
# Out:
# np.False_

# %%
us_jobs = df[df.job_country == 'United States']

# %%
us_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206292 entries, 0 to 785705
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        206292 non-null  object
#  1   job_title              206292 non-null  object
#  2   job_location           205505 non-null  object
#  3   job_via                206285 non-null  object
#  4   job_schedule_type      205099 non-null  object
#  5   job_work_from_home     206292 non-null  bool
#  6   search_location        206292 non-null  object
#  7   job_posted_date        206292 non-null  object
#  8   job_no_degree_mention  206292 non-null  bool
#  9   job_health_insurance   206292 non-null  bool
#  10  job_country            206292 non-null  object
#  11  salary_rate            25372 non-null   object
#  12  salary_year_avg        15766 non-null   float64
#  13  salary_hour_avg        9405 non-null    float64
# ...

# %%
us_jobs.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     15766.000000              0.0
# mean     126134.487958              NaN
# std       48881.042901              NaN
# min       23496.000000              NaN
# 25%       90000.000000              NaN
# 50%      119187.500000              NaN
# 75%      150000.000000              NaN
# max      960000.000000              NaN

# %%
# drop rows where hyearly salary is nan
# both below methods are correct

us_jobs.dropna(subset = 'salary_year_avg', inplace = True)

us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15766 entries, 92 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        15766 non-null  object
#  1   job_title              15766 non-null  object
#  2   job_location           15544 non-null  object
#  3   job_via                15766 non-null  object
#  4   job_schedule_type      15752 non-null  object
#  5   job_work_from_home     15766 non-null  bool
#  6   search_location        15766 non-null  object
#  7   job_posted_date        15766 non-null  object
#  8   job_no_degree_mention  15766 non-null  bool
#  9   job_health_insurance   15766 non-null  bool
#  10  job_country            15766 non-null  object
#  11  salary_rate            15766 non-null  object
#  12  salary_year_avg        15766 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
us_jobs.job_title_short.value_counts()
# Out:
# job_title_short
# Data Scientist               4553
# Data Analyst                 4350
# Data Engineer                2915
# Senior Data Scientist        1241
# Senior Data Engineer         1058
# Senior Data Analyst           913
# Business Analyst              431
# Software Engineer             157
# Machine Learning Engineer     128
# Cloud Engineer                 20
# Name: count, dtype: int64

# %%
us_jobs.groupby(by = ['job_title_short']).count()
# if you dont provide the aggregate column, it is going to perform statistics on all the columns
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                 431           425      431
# Cloud Engineer                    20            20       20
# Data Analyst                    4350          4285     4350
# Data Engineer                   2915          2869     2915
# Data Scientist                  4553          4498     4553
# Machine Learning Engineer        128           128      128
# Senior Data Analyst              913           903      913
# Senior Data Engineer            1058          1041     1058
# Senior Data Scientist           1241          1220     1241
# Software Engineer                157           155      157
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                         430                 431
# Cloud Engineer                            19                  20
# Data Analyst                            4342                4350
# ...

# %%
us_jobs.groupby(by = ['job_title_short'])['salary_year_avg'].count()
# Out:
# job_title_short
# Business Analyst              431
# Cloud Engineer                 20
# Data Analyst                 4350
# Data Engineer                2915
# Data Scientist               4553
# Machine Learning Engineer     128
# Senior Data Analyst           913
# Senior Data Engineer         1058
# Senior Data Scientist        1241
# Software Engineer             157
# Name: salary_year_avg, dtype: int64

# %%
#groupby salary on titles

us_jobs.groupby(by = ['job_title_short'])['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              96175.447397
# Cloud Engineer               120090.900000
# Data Analyst                  94553.964924
# Data Engineer                134226.676753
# Data Scientist               139946.707204
# Machine Learning Engineer    154240.382812
# Senior Data Analyst          115729.129954
# Senior Data Engineer         151448.023186
# Senior Data Scientist        159330.432029
# Software Engineer            137964.929588
# Name: salary_year_avg, dtype: float64

# %%
us_jobs.groupby(by = ['job_title_short'])[['salary_year_avg']].agg(['count','min', 'max', 'median', 'mean'])

# salary_year_avg shows up in column
# Out:
#                           salary_year_avg                               \
#                                     count      min       max    median
# job_title_short
# Business Analyst                      431  35000.0  387460.0   90000.0
# Cloud Engineer                         20  42000.0  221844.0  116100.0
# Data Analyst                         4350  25000.0  375000.0   90000.0
# Data Engineer                        2915  23496.0  525000.0  125000.0
# Data Scientist                       4553  30000.0  960000.0  130000.0
# Machine Learning Engineer             128  44408.5  315000.0  150000.0
# Senior Data Analyst                   913  35360.0  425000.0  110000.0
# Senior Data Engineer                 1058  45000.0  375000.0  150000.0
# Senior Data Scientist                1241  55000.0  475000.0  155000.0
# Software Engineer                     157  48982.0  375000.0  130000.0
#
#
#                                     mean
# job_title_short
# ...

# %%
us_jobs.groupby(by = ['job_title_short'])['salary_year_avg'].agg(['count','min', 'max', 'median', 'mean'])

# salary_year_avg does not show up in column
# Out:
#                            count      min       max    median           mean
# job_title_short
# Business Analyst             431  35000.0  387460.0   90000.0   96175.447397
# Cloud Engineer                20  42000.0  221844.0  116100.0  120090.900000
# Data Analyst                4350  25000.0  375000.0   90000.0   94553.964924
# Data Engineer               2915  23496.0  525000.0  125000.0  134226.676753
# Data Scientist              4553  30000.0  960000.0  130000.0  139946.707204
# Machine Learning Engineer    128  44408.5  315000.0  150000.0  154240.382812
# Senior Data Analyst          913  35360.0  425000.0  110000.0  115729.129954
# Senior Data Engineer        1058  45000.0  375000.0  150000.0  151448.023186
# Senior Data Scientist       1241  55000.0  475000.0  155000.0  159330.432029
# Software Engineer            157  48982.0  375000.0  130000.0  137964.929588

# %%
us_jobs.groupby(by = ['job_title_short'])['salary_year_avg'].agg(['count','min', 'max', 'median', 'mean']).sort_values(by = 'count', ascending = False)
# Out:
#                            count      min       max    median           mean
# job_title_short
# Data Scientist              4553  30000.0  960000.0  130000.0  139946.707204
# Data Analyst                4350  25000.0  375000.0   90000.0   94553.964924
# Data Engineer               2915  23496.0  525000.0  125000.0  134226.676753
# Senior Data Scientist       1241  55000.0  475000.0  155000.0  159330.432029
# Senior Data Engineer        1058  45000.0  375000.0  150000.0  151448.023186
# Senior Data Analyst          913  35360.0  425000.0  110000.0  115729.129954
# Business Analyst             431  35000.0  387460.0   90000.0   96175.447397
# Software Engineer            157  48982.0  375000.0  130000.0  137964.929588
# Machine Learning Engineer    128  44408.5  315000.0  150000.0  154240.382812
# Cloud Engineer                20  42000.0  221844.0  116100.0  120090.900000

# %%
us_jobs.groupby(by = ['job_title_short'])['salary_year_avg'].agg(['count','min', 'max', 'median', 'mean']).sort_values(by = 'median')
# Out:
#                            count      min       max    median           mean
# job_title_short
# Business Analyst             431  35000.0  387460.0   90000.0   96175.447397
# Data Analyst                4350  25000.0  375000.0   90000.0   94553.964924
# Senior Data Analyst          913  35360.0  425000.0  110000.0  115729.129954
# Cloud Engineer                20  42000.0  221844.0  116100.0  120090.900000
# Data Engineer               2915  23496.0  525000.0  125000.0  134226.676753
# Data Scientist              4553  30000.0  960000.0  130000.0  139946.707204
# Software Engineer            157  48982.0  375000.0  130000.0  137964.929588
# Machine Learning Engineer    128  44408.5  315000.0  150000.0  154240.382812
# Senior Data Engineer        1058  45000.0  375000.0  150000.0  151448.023186
# Senior Data Scientist       1241  55000.0  475000.0  155000.0  159330.432029

# %%
df.salary_hour_avg.mean()
# Out:
# np.float64(47.01659821515861)

# %%
df.salary_hour_avg.median()
# Out:
# 45.97999954223633

# %%
df.groupby(by = ['job_title_short'])['salary_hour_avg'].mean()
# Out:
# job_title_short
# Business Analyst             42.723415
# Cloud Engineer               45.560715
# Data Analyst                 38.106918
# Data Engineer                57.196998
# Data Scientist               49.361403
# Machine Learning Engineer    48.477935
# Senior Data Analyst          47.661218
# Senior Data Engineer         62.848496
# Senior Data Scientist        54.105631
# Software Engineer            46.452019
# Name: salary_hour_avg, dtype: float64

# %%
df.groupby(by = ['job_title_short'])['salary_hour_avg'].mean().sort_values()
# Out:
# job_title_short
# Data Analyst                 38.106918
# Business Analyst             42.723415
# Cloud Engineer               45.560715
# Software Engineer            46.452019
# Senior Data Analyst          47.661218
# Machine Learning Engineer    48.477935
# Data Scientist               49.361403
# Senior Data Scientist        54.105631
# Data Engineer                57.196998
# Senior Data Engineer         62.848496
# Name: salary_hour_avg, dtype: float64

# %%
df[['job_title_short','salary_hour_avg']].iloc[df.salary_hour_avg.idxmin()]
# Out:
# job_title_short    Data Scientist
# salary_hour_avg               8.0
# Name: 88185, dtype: object

# %%
df.groupby(by = ['job_country'])['job_country'].count().sort_values(ascending = False)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Bhutan                 3
# Lesotho                3
# Mauritania             3
# Maldives               2
# Name: job_country, Length: 160, dtype: int64

# %%
df.groupby(by = ['job_country']).size().sort_values(ascending = False)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Bhutan                 3
# Lesotho                3
# Mauritania             3
# Maldives               2
# Length: 160, dtype: int64
