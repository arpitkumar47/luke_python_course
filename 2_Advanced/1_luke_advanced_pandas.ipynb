# %%
print("hello")

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# # Accesssing Data

# %%
df.iloc[0:1]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
#
#     job_location          job_via job_schedule_type  job_work_from_home  \
# 0  Watertown, CT  via Work Nearby         Full-time               False
#
#         search_location     job_posted_date  job_no_degree_mention  \
# 0  Texas, United States 2023-06-16 13:44:15                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
#
#    salary_hour_avg          company_name job_skills job_type_skills
# 0              NaN  Boehringer Ingelheim       None            None

# %%
df.iloc[0:10]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df.iloc[0:10,1]
# Out:
# 0    Senior Clinical Data Engineer / Principal Clin...
# 1                                         Data Analyst
# 2    Data Engineer/Scientist/Analyst, Mid or Senior...
# 3    LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                               Data Engineer- Sr Jobs
# 5                                    GCP Data Engineer
# 6                    Senior Data Engineer  - GCP Cloud
# 7                                        Data Engineer
# 8             Technology & Operations Business Analyst
# 9                                    Data Scientist II
# Name: job_title, dtype: object

# %%
df.iloc[0:10,5]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: job_work_from_home, dtype: bool

# %%
df.loc[0:10, "job_work_from_home"]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# Name: job_work_from_home, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.loc[0:10, ['salary_rate', 'salary_year_avg', 'salary_hour_avg' ]]
# Out:
#    salary_rate  salary_year_avg  salary_hour_avg
# 0         None              NaN              NaN
# 1         None              NaN              NaN
# 2         None              NaN              NaN
# 3         None              NaN              NaN
# 4         None              NaN              NaN
# 5         None              NaN              NaN
# 6         None              NaN              NaN
# 7         None              NaN              NaN
# 8         None              NaN              NaN
# 9         None              NaN              NaN
# 10        None              NaN              NaN

# %%
df.loc[0:10, 'salary_rate':'salary_hour_avg']
# Out:
#    salary_rate  salary_year_avg  salary_hour_avg
# 0         None              NaN              NaN
# 1         None              NaN              NaN
# 2         None              NaN              NaN
# 3         None              NaN              NaN
# 4         None              NaN              NaN
# 5         None              NaN              NaN
# 6         None              NaN              NaN
# 7         None              NaN              NaN
# 8         None              NaN              NaN
# 9         None              NaN              NaN
# 10        None              NaN              NaN

# %%
df.loc[:, 'salary_rate':'salary_hour_avg']
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
# [785741 rows x 3 columns]

# %%
df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset = ['salary_rate'])
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
df.iloc[:5,1:3]
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
df.iloc[:5,[1,2]]
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %% [markdown]
# With df.loc, notice the indices and what values are returned

# %%
df.loc[5:9, 'job_title':'job_posted_date']
# Out:
#                                   job_title         job_location  \
# 5                         GCP Data Engineer             Anywhere
# 6         Senior Data Engineer  - GCP Cloud         Dearborn, MI
# 7                             Data Engineer             Anywhere
# 8  Technology & Operations Business Analyst  Copenhagen, Denmark
# 9                         Data Scientist II             Anywhere
#
#             job_via         job_schedule_type  job_work_from_home  \
# 5  via ZipRecruiter  Contractor and Temp work                True
# 6      via LinkedIn                 Full-time               False
# 7      via LinkedIn                 Full-time                True
# 8   via Trabajo.org                 Full-time               False
# 9  via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date
# 5                  Georgia 2023-11-07 14:01:59
# 6   Florida, United States 2023-03-27 13:18:18
# ...

# %%
# retrieving first 15 rows and then filtering on job_country
df.iloc[0:15][df.job_country == 'United States']
# Out:
# /var/folders/9m/z34hzp3d30q874n20_86hvdm0000gn/T/ipykernel_45544/4007501784.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.iloc[0:15][df.job_country == 'United States']
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9         Data Scientist                                  Data Scientist II
# 11         Data Engineer                                      Data Engineer
# 13  Senior Data Engineer                               Senior Data Engineer
#
#                           job_location            job_via  \
# 0                        Watertown, CT    via Work Nearby
# ...

# %%
# Filtering the df on job_country and then retreiving first 15 rows from the filtered df
df[df.job_country == 'United States'].iloc[0:15][['job_title', 'salary_year_avg']]
# Out:
#                                             job_title  salary_year_avg
# 0   Senior Clinical Data Engineer / Principal Clin...              NaN
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...              NaN
# 5                                   GCP Data Engineer              NaN
# 6                   Senior Data Engineer  - GCP Cloud              NaN
# 9                                   Data Scientist II              NaN
# 11                                      Data Engineer              NaN
# 13                               Senior Data Engineer              NaN
# 17                             Data Science Team Lead              NaN
# 26                                      Data Engineer              NaN
# 27  Principal Data Engineer (Lead), Knowledge Grap...              NaN
# 30     Senior Data Engineer (Work from home Eligible)              NaN
# 32   Sr. Data Scientist (NLP) - Full-time / Part-time              NaN
# ...

# %%
df[df.job_posted_date > '2023-05-01'].loc[:,['job_title','job_location','job_posted_date']]
# Out:
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785694                                      Data Engineer
# 785696                          Senior Analytics Engineer
# 785698      Data Engineer, Gerencia Business Intelligence
# 785701      Data Engineer, Gerencia Business Intelligence
# 785706                               Junior Data Engineer
#
#                      job_location     job_posted_date
# 0                   Watertown, CT 2023-06-16 13:44:15
# 2                 Berlin, Germany 2023-10-10 13:14:55
# 3                 San Antonio, TX 2023-07-04 13:01:41
# ...

# %%
df.loc[df.job_posted_date > '2023-05-01', ['job_title','job_location','job_posted_date']]
# Out:
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785694                                      Data Engineer
# 785696                          Senior Analytics Engineer
# 785698      Data Engineer, Gerencia Business Intelligence
# 785701      Data Engineer, Gerencia Business Intelligence
# 785706                               Junior Data Engineer
#
#                      job_location     job_posted_date
# 0                   Watertown, CT 2023-06-16 13:44:15
# 2                 Berlin, Germany 2023-10-10 13:14:55
# 3                 San Antonio, TX 2023-07-04 13:01:41
# ...

# %% [markdown]
# # Cleaning Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.loc[:10, 'salary_year_avg': 'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %%
# fill values with median

# %%
median_yearly_salary = df.salary_year_avg.median()

# %%
median_hourly_salary = df.salary_hour_avg.median()

# %%
df_filled = df

# %%
df_filled['salary_year_avg'] = df_filled.salary_year_avg.fillna(median_yearly_salary)

# %%
df_filled['salary_hour_avg'] = df_filled.salary_hour_avg.fillna(median_hourly_salary)

# %%
df_filled.loc[:10, 'salary_year_avg': 'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %%
# drop duplicates

# %%
df_unique = df_filled

# %%
df_unique = df_unique.drop_duplicates()

# %%
print(len(df_filled))
print(len(df_unique))
print(len(df_filled) - len(df_unique))
# Out:
# 785741
# 785640
# 101

# %%
df_unique = df_unique.drop_duplicates(subset = ['job_title', 'company_name'])

# %%
print(len(df_filled))
print(len(df_unique))
print(len(df_filled) - len(df_unique))
# Out:
# 785741
# 508042
# 277699

# %%
df_1 = df.dropna(subset=['salary_year_avg'])

# %%
print(len(df))
print(len(df_1))
# Out:
# 785741
# 22003

# %%
df_unique2 = df.drop_duplicates(subset=['job_location'])

# %%
print(len(df))
print(len(df_unique2))
# Out:
# 785741
# 17218

# %%
df.salary_rate.fillna('Unknown')[:10]
# Out:
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# 5    Unknown
# 6    Unknown
# 7    Unknown
# 8    Unknown
# 9    Unknown
# Name: salary_rate, dtype: object

# %% [markdown]
# # Data Management

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
# sample

# %%
df.sample()
# Out:
#       job_title_short     job_title              job_location  \
# 62939  Data Scientist  Head of Data  Melbourne VIC, Australia
#
#                job_via job_schedule_type  job_work_from_home search_location  \
# 62939  via Trabajo.org         Full-time               False       Australia
#
#           job_posted_date  job_no_degree_mention  job_health_insurance  \
# 62939 2023-11-02 06:15:48                   True                 False
#
#       job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 62939   Australia        None              NaN              NaN
#
#          company_name job_skills job_type_skills
# 62939  Australia Post       None            None

# %%
df.sample(10) # 10 samples
# Out:
#               job_title_short                                       job_title  \
# 508568         Data Scientist         Associate Director, MSAT - Data Science
# 332908         Data Scientist                                  DATA SCIENTIST
# 453256          Data Engineer                        Data Engineer Splunk H/F
# 65893            Data Analyst                       Data Intelligence Analyst
# 227630         Data Scientist  Internship: Data Scientist, Health Informatics
# 726549          Data Engineer                                   Data Engineer
# 38592           Data Engineer                      BI Data Engineer Freelance
# 116676         Data Scientist                                  Data Scientist
# 617432  Senior Data Scientist                           Senior Data Scientist
# 618667           Data Analyst                             expert data analyst
#
#                job_location                        job_via job_schedule_type  \
# ...

# %%
df.sample(10, random_state= 42) # assigning random state
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
df.sample(frac=0.1) # 10% sample
# Out:
#              job_title_short  \
# 483601        Data Scientist
# 55064           Data Analyst
# 701368  Senior Data Engineer
# 45997      Software Engineer
# 8954           Data Engineer
# ...                      ...
# 739119        Cloud Engineer
# 536886        Data Scientist
# 218755          Data Analyst
# 353462         Data Engineer
# 680401         Data Engineer
#
#                                                 job_title  \
# 483601                           Principal Data Scientist
# 55064                                        Data Analyst
# 701368   Sr. Developer / Sr. Data Engineer Snowflake(AWS)
# 45997                                  Principal Engineer
# 8954                                        Data Engineer
# ...                                                   ...
# 739119                                 Fullstack Engineer
# 536886  Statistician for the epidemiology/ real-world ...
# 218755                             Marketing Data Analyst
# ...

# %%
# copy

# %%
df_copy1 = df

# %%
df_copy2 = df.copy()

# %%
median_yearly_salary1 = df_copy1.salary_year_avg.median()

# %%
median_hourly_salary2 = df_copy2.salary_hour_avg.median()

# %%
df_copy1['salary_year_avg'] = df_copy1.salary_year_avg.fillna(median_yearly_salary1)

# %%
df_copy2['salary_hour_avg'] = df_copy2.salary_hour_avg.fillna(median_hourly_salary2)

# %%
df_copy1['salary_year_avg'].head()
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df['salary_year_avg'].head()
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df['salary_hour_avg'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: salary_hour_avg, dtype: float64

# %%
df_copy2['salary_hour_avg'].head()
# Out:
# 0    45.98
# 1    45.98
# 2    45.98
# 3    45.98
# 4    45.98
# Name: salary_hour_avg, dtype: float64

# %%
id(df)
# Out:
# 13236391504

# %%
id(df_copy1)
# Out:
# 13236391504

# %%
id(df_copy2)
# Out:
# 13108110160

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.dropna(subset=['salary_year_avg'])

# %%
len(df)
# Out:
# 785741

# %%
len(df_copy)
# Out:
# 22003

# %%
df.sample( int(len(df)*0.1))
# Out:
#               job_title_short  \
# 326235  Senior Data Scientist
# 42875          Data Scientist
# 366784           Data Analyst
# 235232          Data Engineer
# 345429           Data Analyst
# ...                       ...
# 128217          Data Engineer
# 672598         Data Scientist
# 396722         Cloud Engineer
# 157960          Data Engineer
# 265367           Data Analyst
#
#                                                 job_title  \
# 326235                              Senior Data Scientist
# 42875   Data Scientist, Environmental Health and Extre...
# 366784                                       Data Analyst
# 235232                          Data & Reporting Engineer
# 345429                                       Data Analyst
# ...                                                   ...
# 128217                                    Data Engineer 4
# 672598                            Data Scientist III - MX
# 396722                                 QC Analyst Project
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
df_copy = df.copy()

# %%
df_copy.salary_year_avg.fillna(df_copy.salary_year_avg.median()).head(5)
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# # pivot tables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.pivot_table(index = 'job_title_short', aggfunc= 'size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
# size vs count
# size counts all the rows in a group
# count returns the non null rows in a group

# %%
df.groupby(by = ['job_title_short']).size()
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table(index = 'job_title_short', aggfunc= 'count')
# Out:
#                            company_name  job_country  job_health_insurance  \
# job_title_short
# Business Analyst                  49063        49057                 49063
# Cloud Engineer                    12331        12329                 12331
# Data Analyst                     196070       196067                196075
# Data Engineer                    186236       186237                186241
# Data Scientist                   172281       172281                172286
# Machine Learning Engineer         14080        14078                 14080
# Senior Data Analyst               29216        29214                 29216
# Senior Data Engineer              44563        44561                 44563
# Senior Data Scientist             36957        36956                 36957
# Software Engineer                 44926        44912                 44929
#
#                            job_location  job_no_degree_mention  \
# job_title_short
# ...

# %%
df.pivot_table(index = 'job_title_short', values='salary_year_avg', aggfunc= 'median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
# get rows where salary is > 100_000
df[df.salary_year_avg > 100_000].groupby(by = 'job_title_short')[['salary_year_avg']].median()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                  125000.0
# Cloud Engineer                    151000.0
# Data Analyst                      115000.0
# Data Engineer                     140000.0
# Data Scientist                    147500.0
# Machine Learning Engineer         166000.0
# Senior Data Analyst               119400.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             157500.0
# Software Engineer                 155000.0

# %%
df[df.job_country == 'United States'].groupby(by = 'job_title_short')[['salary_year_avg']].median()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   90000.0
# Cloud Engineer                    116100.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    130000.0
# Machine Learning Engineer         150000.0
# Senior Data Analyst               110000.0
# Senior Data Engineer              150000.0
# Senior Data Scientist             155000.0
# Software Engineer                 130000.0

# %%
df.pivot_table(index = ['job_title_short'], columns = ['job_country'], values='salary_year_avg', aggfunc= 'median')
# Out:
# job_country                  Albania  Algeria  Argentina   Armenia  Australia  \
# job_title_short
# Business Analyst                 NaN      NaN   71100.00       NaN    70000.0
# Cloud Engineer                   NaN      NaN  197500.00       NaN   110000.0
# Data Analyst                49950.00  44100.0   92771.75  100500.0   109500.0
# Data Engineer                    NaN  45000.0   96773.00   48750.0   106712.5
# Data Scientist              69981.25      NaN   71000.00       NaN   139216.0
# Machine Learning Engineer        NaN      NaN  101029.00   87021.0   101029.0
# Senior Data Analyst              NaN      NaN        NaN       NaN    50640.0
# Senior Data Engineer             NaN      NaN  147500.00       NaN   147500.0
# Senior Data Scientist      157500.00      NaN        NaN       NaN   157500.0
# Software Engineer                NaN      NaN  174500.00       NaN   118350.0
#
# job_country                  Austria  Azerbaijan   Bahamas  Bangladesh  \
# job_title_short
# ...

# %%
df.pivot_table(index = ['job_country'] , columns = ['job_title_short'], values=['salary_year_avg','salary_hour_avg'], aggfunc= ['mean','median'])
# Out:
#                             mean                                            \
#                  salary_hour_avg
# job_title_short Business Analyst Cloud Engineer Data Analyst Data Engineer
# job_country
# Albania                      NaN            NaN          NaN           NaN
# Algeria                      NaN            NaN        15.00          25.0
# Argentina                    NaN            NaN          NaN          80.0
# Armenia                      NaN            NaN          NaN           NaN
# Australia                   20.0           20.0        21.25          20.0
# ...                          ...            ...          ...           ...
# Uzbekistan                   NaN            NaN          NaN           NaN
# Venezuela                    NaN            NaN          NaN          80.0
# Vietnam                      NaN            NaN          NaN           NaN
# Zambia                       NaN            NaN          NaN           NaN
# ...

# %%
# build a pivot table for top 6 countries with the median salaries of top 3 job titles in those countries

top_countries = df.job_country.value_counts().head(6)
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Name: count, dtype: int64

# %%
top_countries = df.job_country.value_counts().head(6).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
# top 3 jobs

top_jobs = df[df.job_country.isin(top_countries)].job_title_short.value_counts().head(3)
top_jobs
# Out:
# job_title_short
# Data Analyst      110530
# Data Scientist    103097
# Data Engineer      90300
# Name: count, dtype: int64

# %%
# top 3 jobs in top 6 countries

top_jobs = df[df.job_country.isin(top_countries)].job_title_short.value_counts().head(3)
top_jobs
# Out:
# job_title_short
# Data Analyst      110530
# Data Scientist    103097
# Data Engineer      90300
# Name: count, dtype: int64

# %%
top_jobs = df[df.job_country.isin(top_countries)].job_title_short.value_counts().head(3).index
top_jobs
# Out:
# Index(['Data Analyst', 'Data Scientist', 'Data Engineer'], dtype='object', name='job_title_short')

# %%
df[(df.job_country.isin(top_countries)) & (df.job_title_short.isin(top_jobs))].pivot_table(index = 'job_country', aggfunc= 'median', values= 'salary_year_avg', columns= 'job_title_short')
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0
# India                100500.0       147500.0        114008.0
# Spain                 91977.0       133000.0         88128.0
# United Kingdom        87750.0       110000.0        105300.0
# United States         90000.0       125000.0        130000.0

# %%
df_pivot = df[(df.job_country.isin(top_countries)) & (df.job_title_short.isin(top_jobs))].pivot_table(index = 'job_country', aggfunc= 'median', values= 'salary_year_avg', columns= 'job_title_short')

# %%
df_pivot.sort_values(by = 'job_country', ascending= False)
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# United Kingdom        87750.0       110000.0        105300.0
# Spain                 91977.0       133000.0         88128.0
# India                100500.0       147500.0        114008.0
# Germany              103750.0       147500.0        131560.0
# France                69175.0        98301.5         88128.0

# %%
df_pivot.sort_values(by = 'Data Analyst', ascending= False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
type(df_pivot)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pivot.loc[top_countries]
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# India                100500.0       147500.0        114008.0
# United Kingdom        87750.0       110000.0        105300.0
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0
# Spain                 91977.0       133000.0         88128.0

# %%
df[(df.job_country.isin(top_countries)) & (df.job_title_short.isin(top_jobs))].pivot_table(index = 'job_country', aggfunc= 'median', values= 'salary_year_avg', columns= 'job_title_short').plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df.pivot_table(index = ['job_title_short', 'job_country'], aggfunc= 'size').head(10)
# Out:
# job_title_short   job_country
# Business Analyst  Afghanistan      4
#                   Albania         11
#                   Algeria         21
#                   Angola           1
#                   Argentina      453
#                   Armenia         29
#                   Australia      928
#                   Austria        738
#                   Azerbaijan      16
#                   Bahamas          5
# dtype: int64

# %%
df.groupby(by = ['company_name'])['salary_year_avg'].agg(['max', 'min', 'mean']).head(5)
# Out:
#                                              max  min  mean
# company_name
# "Dbank"                                      NaN  NaN   NaN
# "Hamkorbank" АТБ                             NaN  NaN   NaN
# "KELKOO"                                     NaN  NaN   NaN
# "PASHA Holding" LLC                          NaN  NaN   NaN
# "TECHNICUS LTD" sp. z o.o. ODDZIAŁ W POLSCE  NaN  NaN   NaN

# %%
df.pivot_table(index = 'company_name', values= 'salary_year_avg', aggfunc= ['max', 'min', 'mean']).head(5)
# Out:
#                                     max             min            mean
#                         salary_year_avg salary_year_avg salary_year_avg
# company_name
# #twiceasnice Recruiting   120000.000000    61000.000000    77750.000000
# /dev/color                125000.000000   125000.000000   125000.000000
# 0nward Select              92500.000000    92500.000000    92500.000000
# 1 Point System            137290.484375   137290.484375   137290.484375
# 1 Point System LLC.       170000.000000   170000.000000   170000.000000

# %%
df.groupby(by = ['company_name', 'job_country'])[['salary_year_avg']].median()
# Out:
#                                                            salary_year_avg
# company_name                                job_country
# "Dbank"                                     Pakistan                   NaN
# "Hamkorbank" АТБ                            Uzbekistan                 NaN
# "KELKOO"                                    France                     NaN
# "PASHA Holding" LLC                         Azerbaijan                 NaN
# "TECHNICUS LTD" sp. z o.o. ODDZIAŁ W POLSCE Poland                     NaN
# ...                                                                    ...
# 𝐏𝐓 𝐌𝐢𝐭𝐫𝐚 𝐏𝐢𝐧𝐚𝐬𝐭𝐡𝐢𝐤𝐚 𝐌𝐮𝐬𝐭𝐢𝐤𝐚 𝐑𝐞𝐧𝐭 (𝐌𝐏𝐌 𝐑𝐞𝐧𝐭) Indonesia                  NaN
# 🇮🇳 easyfix.in                               India                      NaN
# 🏛️WalletConnect                             United States              NaN
# 💻 LGA IT                                    Belgium                    NaN
# 💾Data Trust Associates                      Belgium                    NaN
#
# ...

# %%
df.pivot_table(index = ['company_name'], columns= 'job_country', values = 'salary_year_avg', aggfunc= 'median')
# Out:
# job_country                         Albania  Algeria  Argentina  Armenia  \
# company_name
# #twiceasnice Recruiting                 NaN      NaN        NaN      NaN
# /dev/color                              NaN      NaN        NaN      NaN
# 0nward Select                           NaN      NaN        NaN      NaN
# 1 Point System                          NaN      NaN        NaN      NaN
# 1 Point System LLC.                     NaN      NaN        NaN      NaN
# ...                                     ...      ...        ...      ...
# zooplus SE                              NaN      NaN        NaN      NaN
# ztp                                     NaN      NaN        NaN      NaN
# ЛАНИТ                                   NaN      NaN        NaN      NaN
# Технологическая компания                NaN      NaN        NaN      NaN
# ​Illinois State Board of Education      NaN      NaN        NaN      NaN
#
# ...

# %%
df_pivot = df[df.job_title == 'Data Scientist'].pivot_table(index = ['company_name'], columns= 'job_country', values = 'salary_year_avg', aggfunc= 'median')
df_pivot
# Out:
# job_country      Argentina  Australia  Belgium  Bulgaria  Canada  Colombia  \
# company_name
# 1872 Consulting        NaN        NaN      NaN       NaN     NaN       NaN
# 2K                     NaN        NaN      NaN       NaN     NaN       NaN
# 2U                     NaN        NaN      NaN       NaN     NaN       NaN
# 3B Staffing LLC        NaN        NaN      NaN       NaN     NaN       NaN
# 3Red Partners          NaN        NaN      NaN       NaN     NaN       NaN
# ...                    ...        ...      ...       ...     ...       ...
# iOLAP                  NaN        NaN      NaN       NaN     NaN       NaN
# jerry.ai               NaN        NaN      NaN       NaN     NaN       NaN
# murmuration            NaN        NaN      NaN       NaN     NaN       NaN
# pulseData              NaN        NaN      NaN       NaN     NaN       NaN
# usagov                 NaN        NaN      NaN       NaN     NaN       NaN
#
# ...

# %%
df_company_median = df.groupby(by = 'company_name')[['salary_year_avg']].median()
company_median_high = df_company_median[df_company_median.salary_year_avg>200_000].index
company_median_high
# Out:
# Index(['6sense', 'ACT', 'AI Startup', 'ANSER Corporation', 'Abridge',
#        'Acquire Me', 'Airbnb', 'Airtable', 'Akamai', 'Algo Capital Group',
#        ...
#        'YETI Coolers', 'ZealoTech People', 'Zocdoc', 'Zoox', 'Zoox.com',
#        'expand group', 'nitruc', 'orbit', 'ЛАНИТ', 'Технологическая компания'],
#       dtype='object', name='company_name', length=208)

# %%
df_pivot_2 = df[(df.job_title == 'Data Scientist') & (df.company_name.isin(company_median_high))].pivot_table(index = ['company_name','job_country'], values = 'salary_year_avg', aggfunc= 'median').head(10)
df_pivot_2
# Out:
#                                                            salary_year_avg
# company_name                                job_country
# Airtable                                    Sudan                 215500.0
# Algo Capital Group                          Sudan                 325000.0
#                                             United States         350000.0
# East River Electric Power Cooperative, Inc. United States         537000.0
# Genentech                                   United States         106250.0
# Grammarly                                   Sudan                 186000.0
#                                             United States         204500.0
# INgrooves Music Group                       United States         250000.0
# INgroovesMusicGroup                         United States         250000.0
# Radley James                                United States         225000.0

# %% [markdown]
# # index management

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.sample(5)
# Out:
#               job_title_short                                    job_title  \
# 583798         Data Scientist                           Analytics Engineer
# 691641  Senior Data Scientist  Senior Data Mining Expert 000002  5003856HO
# 760999         Data Scientist                  Data Scientist Associate Sr
# 641832          Data Engineer                                Data Engineer
# 760273      Software Engineer                    ETL/Informatica Developer
#
#                        job_location          job_via job_schedule_type  \
# 583798             Barcelona, Spain     via LinkedIn         Full-time
# 691641                 Saudi Arabia  via Trabajo.org         Full-time
# 760999  Hyderabad, Telangana, India  via BeBee India         Full-time
# 641832     Melbourne VIC, Australia  via SimplyHired         Full-time
# 760273                       Brazil        via BeBee         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# ...

# %%
df.index.name

# %%
# naming an index

df.index.name = 'job_index'

# %%
df.sample(5)
# Out:
#                      job_title_short                              job_title  \
# job_index
# 744905                Data Scientist    HRIS Analyst - Core HCM & Analytics
# 85295      Machine Learning Engineer                  Senior AI/ML Engineer
# 203593                Data Scientist                         Data Scientist
# 252699                 Data Engineer  Senior Data Engineer (all genders) AI
# 63203                   Data Analyst            Medical Information Analyst
#
#                            job_location                            job_via  \
# job_index
# 744905                    Las Vegas, NV                    via GameJobs.co
# 85295      Collegeville, PA (+4 others)  via GSK Careers Job Search - Jobs
# 203593                     New York, NY                           via Dice
# 252699                  Munich, Germany                    via Recruit.net
# 63203                  Casariche, Spain                          via BeBee
#
# ...

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df.job_country == 'United States']

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
# reset index

# %%
df_usa.reset_index(inplace=True) # creates a new index

# %%
df_usa.head(10)
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
# 5         11         Data Engineer
# 6         13  Senior Data Engineer
# 7         17        Data Scientist
# 8         26         Data Engineer
# 9         27         Data Engineer
#
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2                                  GCP Data Engineer
# 3                  Senior Data Engineer  - GCP Cloud
# 4                                  Data Scientist II
# 5                                      Data Engineer
# 6                               Senior Data Engineer
# 7                             Data Science Team Lead
# 8                                      Data Engineer
# ...

# %%
# set index
# use existing column as index

df_usa.set_index('job_index', inplace=True)

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
median_pivot = df_usa.pivot_table(index = 'job_title_short', values = 'salary_year_avg', aggfunc=['median', 'min', 'max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by = ('median', 'salary_year_avg'), ascending= False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                130000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_index(inplace=True)

# %%
# trends of jobs in USA over time

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.sample(5)
# Out:
#           job_title_short                                     job_title  \
# job_index
# 351499      Data Engineer  Research Data Engineer for the Health Domain
# 70055      Data Scientist                                Data Scientist
# 547702     Data Scientist                                Data Scientist
# 450083      Data Engineer                  Data Engineer (Azure Python)
# 702701      Data Engineer                                 Data Engineer
#
#                                                 job_location  \
# job_index
# 351499                         Donostia-San Sebastian, Spain
# 70055                            Bengaluru, Karnataka, India
# 547702                                           Augusta, GA
# 450083                                           Madison, WI
# 702701     Kuala Lumpur, Federal Territory of Kuala Lumpu...
#
#                      job_via job_schedule_type  job_work_from_home  \
# job_index
# ...

# %%
# all jobs in USA
df_usa = df[df.job_country=='United States']
# Out:
# /var/folders/9m/z34hzp3d30q874n20_86hvdm0000gn/T/ipykernel_45544/371143617.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['job_posted_month'] = df_usa.job_posted_date.dt.month

# %%
df_usa['job_posted_month'] = df_usa.job_posted_date.dt.month
df_usa['job_posted_month_name'] = df_usa.job_posted_date.dt.strftime('%b')
# Out:
# /var/folders/9m/z34hzp3d30q874n20_86hvdm0000gn/T/ipykernel_45544/3570316413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['job_posted_month'] = df_usa.job_posted_date.dt.month
# /var/folders/9m/z34hzp3d30q874n20_86hvdm0000gn/T/ipykernel_45544/3570316413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['job_posted_month_name'] = df_usa.job_posted_date.dt.strftime('%b')

# %%
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206292 entries, 0 to 785705
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        206292 non-null  object
#  1   job_title              206292 non-null  object
#  2   job_location           205505 non-null  object
#  3   job_via                206285 non-null  object
#  4   job_schedule_type      205099 non-null  object
#  5   job_work_from_home     206292 non-null  bool
#  6   search_location        206292 non-null  object
#  7   job_posted_date        206292 non-null  datetime64[ns]
#  8   job_no_degree_mention  206292 non-null  bool
#  9   job_health_insurance   206292 non-null  bool
#  10  job_country            206292 non-null  object
#  11  salary_rate            25372 non-null   object
#  12  salary_year_avg        15766 non-null   float64
#  13  salary_hour_avg        9405 non-null    float64
# ...

# %%
df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
# top 3 jobs in USA by count
top_jobs_usa = df_usa.job_title_short.value_counts().head(3).index

top_jobs_usa
# Out:
# Index(['Data Analyst', 'Data Scientist', 'Data Engineer'], dtype='object', name='job_title_short')

# %%
df_usa.pivot_table(index = 'job_title_short', columns = 'job_posted_month_name', aggfunc= 'size').loc[top_jobs_usa]
# Out:
# job_posted_month_name   Apr   Aug   Dec   Feb   Jan   Jul   Jun   Mar   May  \
# job_title_short
# Data Analyst           6049  6634  3979  6124  8494  5201  5683  6218  4993
# Data Scientist         4867  6318  3472  4956  6915  4876  4645  4779  4377
# Data Engineer          2801  3269  2641  3060  2655  2570  2893  3183  2976
#
# job_posted_month_name   Nov   Oct   Sep
# job_title_short
# Data Analyst           4531  5271  4639
# Data Scientist         4175  4882  4568
# Data Engineer          2793  3015  3224

# %%
df_usa_pivot = df_usa.pivot_table(columns = 'job_title_short', index = 'job_posted_month_name', aggfunc= 'size').loc[:,top_jobs_usa]
df_usa_pivot
# Out:
# job_title_short        Data Analyst  Data Scientist  Data Engineer
# job_posted_month_name
# Apr                            6049            4867           2801
# Aug                            6634            6318           3269
# Dec                            3979            3472           2641
# Feb                            6124            4956           3060
# Jan                            8494            6915           2655
# Jul                            5201            4876           2570
# Jun                            5683            4645           2893
# Mar                            6218            4779           3183
# May                            4993            4377           2976
# Nov                            4531            4175           2793
# Oct                            5271            4882           3015
# Sep                            4639            4568           3224

# %%
df_usa_pivot.reset_index(inplace=True)

df_usa_pivot
# Out:
# job_title_short job_posted_month_name  Data Analyst  Data Scientist  \
# 0                                 Apr          6049            4867
# 1                                 Aug          6634            6318
# 2                                 Dec          3979            3472
# 3                                 Feb          6124            4956
# 4                                 Jan          8494            6915
# 5                                 Jul          5201            4876
# 6                                 Jun          5683            4645
# 7                                 Mar          6218            4779
# 8                                 May          4993            4377
# 9                                 Nov          4531            4175
# 10                                Oct          5271            4882
# 11                                Sep          4639            4568
#
# job_title_short  Data Engineer
# 0                         2801
# ...

# %%
df_usa_pivot['job_month_num'] = pd.to_datetime(df_usa_pivot.job_posted_month_name, format='%b').dt.month
df_usa_pivot
# Out:
# job_title_short job_posted_month_name  Data Analyst  Data Scientist  \
# 0                                 Apr          6049            4867
# 1                                 Aug          6634            6318
# 2                                 Dec          3979            3472
# 3                                 Feb          6124            4956
# 4                                 Jan          8494            6915
# 5                                 Jul          5201            4876
# 6                                 Jun          5683            4645
# 7                                 Mar          6218            4779
# 8                                 May          4993            4377
# 9                                 Nov          4531            4175
# 10                                Oct          5271            4882
# 11                                Sep          4639            4568
#
# job_title_short  Data Engineer  job_month_num
# ...

# %%
df_usa_pivot.sort_values(by = 'job_month_num', inplace = True)

df_usa_pivot
# Out:
# job_title_short job_posted_month_name  Data Analyst  Data Scientist  \
# 4                                 Jan          8494            6915
# 3                                 Feb          6124            4956
# 7                                 Mar          6218            4779
# 0                                 Apr          6049            4867
# 8                                 May          4993            4377
# 6                                 Jun          5683            4645
# 5                                 Jul          5201            4876
# 1                                 Aug          6634            6318
# 11                                Sep          4639            4568
# 10                                Oct          5271            4882
# 9                                 Nov          4531            4175
# 2                                 Dec          3979            3472
#
# job_title_short  Data Engineer  job_month_num
# ...

# %%
df_usa_pivot.set_index('job_posted_month_name', inplace = True)

# %%
df_usa_pivot
# Out:
# job_title_short        Data Analyst  Data Scientist  Data Engineer
# job_posted_month_name
# Jan                            8494            6915           2655
# Feb                            6124            4956           3060
# Mar                            6218            4779           3183
# Apr                            6049            4867           2801
# May                            4993            4377           2976
# Jun                            5683            4645           2893
# Jul                            5201            4876           2570
# Aug                            6634            6318           3269
# Sep                            4639            4568           3224
# Oct                            5271            4882           3015
# Nov                            4531            4175           2793
# Dec                            3979            3472           2641

# %%
# df_usa_pivot.drop(columns = 'job_month_num', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[323], line 1
# ----> 1 df_usa_pivot.drop(columns = 'job_month_num', inplace = True)
#
# File /opt/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df_usa_pivot.loc[:,top_jobs_usa].plot()
# Out:
# <Axes: xlabel='job_posted_month_name'>

# %%
df_usa.loc["Data Analyst"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Data Analyst'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[268], line 1
# ----> 1 df_usa.loc["Data Analyst"]
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_exercise = df.copy()

# %%
df_exercise.set_index('job_posted_date', inplace=True)

# %%
df_exercise.head()
# Out:
#                           job_title_short  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Data Engineer
# 2023-01-14 13:18:07          Data Analyst
# 2023-10-10 13:14:55         Data Engineer
# 2023-07-04 13:01:41         Data Engineer
# 2023-08-07 14:29:36         Data Engineer
#
#                                                              job_title  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Clinical Data Engineer / Principal Clin...
# 2023-01-14 13:18:07                                       Data Analyst
# 2023-10-10 13:14:55  Data Engineer/Scientist/Analyst, Mid or Senior...
# 2023-07-04 13:01:41  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2023-08-07 14:29:36                             Data Engineer- Sr Jobs
#
#                                      job_location             job_via  \
# job_posted_date
# 2023-06-16 13:44:15                 Watertown, CT     via Work Nearby
# 2023-01-14 13:18:07  Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
# drop old index
# 
df_exercise.reset_index(drop=True)
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_exercise_pivot = df_exercise.pivot_table(aggfunc=['median'], index = 'company_name', values = 'salary_year_avg')

# %%
df_exercise_pivot.index.name
# Out:
# 'company_name'

# %%
df_exercise_pivot.sort_index(inplace = True, ascending= False)

# %%
df_exercise_pivot
# Out:
#                                             median
#                                    salary_year_avg
# company_name
# ​Illinois State Board of Education    62536.000000
# Технологическая компания             280000.000000
# ЛАНИТ                                400000.000000
# ztp                                   95000.000000
# zooplus SE                           161750.000000
# ...                                            ...
# 1 Point System LLC.                  170000.000000
# 1 Point System                       137290.484375
# 0nward Select                         92500.000000
# /dev/color                           125000.000000
# #twiceasnice Recruiting               65000.000000
#
# [7316 rows x 1 columns]

# %%
df_exercise_pivot = df_exercise.pivot_table(index = 'job_title_short', values = 'salary_year_avg', aggfunc='median')
df_exercise_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df_exercise_pivot.reset_index(inplace = True)

# %%
df_exercise_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
df_exercise_pivot.set_index('salary_year_avg', inplace=True)

# %%
df_exercise_pivot.head()
# Out:
#                   job_title_short
# salary_year_avg
# 85000.0          Business Analyst
# 90000.0            Cloud Engineer
# 90000.0              Data Analyst
# 125000.0            Data Engineer
# 127500.0           Data Scientist

# %% [markdown]
# # Merge DataFrames

# %%
# df1, df2

# df1.merge(df2, how = 'inner', on = 'id', left_on = 'id1', right_on = 'id2')

# %%
df_US_software_pivot = pd.read_csv('https://lukeb.co/software_csv')

df_US_software_pivot
# Out:
#    job_posted_month  Front-End Developer  Back-End Developer  \
# 0           January                13619                9827
# 1          February                11456                9116
# 2             March                11102                8178
# 3             April                14037                9209
# 4               May                12126                8864
# 5              June                12003                8065
# 6              July                11914                8061
# 7            August                11571                8191
# 8         September                14016                8447
# 9           October                11419                8476
# 10         November                13771                9034
# 11         December                14033                9232
#
#     Full-Stack Developer  UI/UX Designer
# 0                   5108            4348
# 1                   7298            4284
# 2                   5814            4159
# ...

# %%
df_US_software_pivot.set_index('job_posted_month', inplace=True)

# %%
df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_usa_pivot
# Out:
# job_title_short        Data Analyst  Data Scientist  Data Engineer
# job_posted_month_name
# Jan                            8494            6915           2655
# Feb                            6124            4956           3060
# Mar                            6218            4779           3183
# Apr                            6049            4867           2801
# May                            4993            4377           2976
# Jun                            5683            4645           2893
# Jul                            5201            4876           2570
# Aug                            6634            6318           3269
# Sep                            4639            4568           3224
# Oct                            5271            4882           3015
# Nov                            4531            4175           2793
# Dec                            3979            3472           2641

# %%
df_usa_pivot.reset_index(inplace = True)

# %%
df_usa_pivot
# Out:
# job_title_short job_posted_month_name  Data Analyst  Data Scientist  \
# 0                                 Jan          8494            6915
# 1                                 Feb          6124            4956
# 2                                 Mar          6218            4779
# 3                                 Apr          6049            4867
# 4                                 May          4993            4377
# 5                                 Jun          5683            4645
# 6                                 Jul          5201            4876
# 7                                 Aug          6634            6318
# 8                                 Sep          4639            4568
# 9                                 Oct          5271            4882
# 10                                Nov          4531            4175
# 11                                Dec          3979            3472
#
# job_title_short  Data Engineer
# 0                         2655
# ...

# %%
df_usa_pivot['job_posted_month_name'] = pd.to_datetime(df_usa_pivot.job_posted_month_name, format= '%b').dt.strftime('%B')

# %%
df_usa_pivot
# Out:
# job_title_short job_posted_month_name  Data Analyst  Data Scientist  \
# 0                             January          8494            6915
# 1                            February          6124            4956
# 2                               March          6218            4779
# 3                               April          6049            4867
# 4                                 May          4993            4377
# 5                                June          5683            4645
# 6                                July          5201            4876
# 7                              August          6634            6318
# 8                           September          4639            4568
# 9                             October          5271            4882
# 10                           November          4531            4175
# 11                           December          3979            3472
#
# job_title_short  Data Engineer
# 0                         2655
# ...

# %%
df_usa_pivot.set_index('job_posted_month_name', inplace = True)

# %%
df_usa_pivot.reset_index(inplace = True)

# %%
df_US_software_pivot.reset_index(inplace = True)

# %%
df_usa_jobs = df_usa_pivot.merge(df_US_software_pivot, how = 'inner', left_on='job_posted_month_name', right_on='job_posted_month')
df_usa_jobs.drop(columns='job_posted_month', inplace = True)

# %%
df_usa_jobs
# Out:
#    job_posted_month_name  Data Analyst  Data Scientist  Data Engineer  \
# 0                January          8494            6915           2655
# 1               February          6124            4956           3060
# 2                  March          6218            4779           3183
# 3                  April          6049            4867           2801
# 4                    May          4993            4377           2976
# 5                   June          5683            4645           2893
# 6                   July          5201            4876           2570
# 7                 August          6634            6318           3269
# 8              September          4639            4568           3224
# 9                October          5271            4882           3015
# 10              November          4531            4175           2793
# 11              December          3979            3472           2641
#
# ...

# %%
df_usa_jobs.set_index('job_posted_month_name', drop=True, inplace= True)

# %%
df_usa_jobs
# Out:
#                        Data Analyst  Data Scientist  Data Engineer  \
# job_posted_month_name
# January                        8494            6915           2655
# February                       6124            4956           3060
# March                          6218            4779           3183
# April                          6049            4867           2801
# May                            4993            4377           2976
# June                           5683            4645           2893
# July                           5201            4876           2570
# August                         6634            6318           3269
# September                      4639            4568           3224
# October                        5271            4882           3015
# November                       4531            4175           2793
# December                       3979            3472           2641
#
#                        Front-End Developer  Back-End Developer  \
# ...

# %%
(df_usa_jobs
 .sum()
 .sort_values(ascending = False)
 .plot(kind = 'barh', label = 'Top Jobs')
 )
plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_us_jobs = df[df.job_country == 'United States'].copy()

# %%
df_us_jobs['job_posted_month'] = df_us_jobs.job_posted_date.dt.month

# %%
df_monthly_postings = pd.DataFrame(df_us_jobs.groupby(by = ['job_posted_month']).size())

# %%
df_monthly_postings
# Out:
#                       0
# job_posted_month
# 1                 22670
# 2                 18020
# 3                 17904
# 4                 17282
# 5                 15283
# 6                 16694
# 7                 16210
# 8                 21029
# 9                 16313
# 10                16998
# 11                14736
# 12                13153

# %%
pd.merge(df_us_jobs, df_monthly_postings, on = 'job_posted_month', how = 'right').head()
# Out:
#     job_title_short                     job_title    job_location  \
# 0     Data Engineer                 Data Engineer  Fort Worth, TX
# 1     Data Engineer                 Data Engineer   San Mateo, CA
# 2  Business Analyst  Business Intelligence Intern      Dallas, TX
# 3     Data Engineer                 Data Engineer  Cincinnati, OH
# 4      Data Analyst                  Data Analyst       Tampa, FL
#
#            job_via job_schedule_type  job_work_from_home  \
# 0     via LinkedIn         Full-time               False
# 1     via LinkedIn         Full-time               False
# 2     via LinkedIn         Full-time               False
# 3  via SimplyHired         Full-time               False
# 4     via LinkedIn         Full-time               False
#
#              search_location     job_posted_date  job_no_degree_mention  \
# 0       Texas, United States 2023-01-25 13:24:01                  False
# 1  California, United States 2023-01-28 13:07:30                  False
# ...

# %%
df_monthly_postings = df_us_jobs.groupby('')
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
df_not_remote_jobs = df[df.job_work_from_home == False].copy()

# %%
df_not_remote_jobs
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
df_not_remote_salary = df_not_remote_jobs.pivot_table(index = 'job_title_short', values = 'salary_year_avg', aggfunc='mean')

# %%
df_not_remote_salary.rename(columns = {'salary_year_avg':'salary_not_remote_avg'}, inplace= True)

# %%
df_not_remote_salary
# Out:
#                            salary_not_remote_avg
# job_title_short
# Business Analyst                    90177.419940
# Cloud Engineer                     105508.026786
# Data Analyst                        93754.956809
# Data Engineer                      129747.517613
# Data Scientist                     134405.937420
# Machine Learning Engineer          125163.597015
# Senior Data Analyst                114051.799273
# Senior Data Engineer               145330.070790
# Senior Data Scientist              151774.688222
# Software Engineer                  111894.697884

# %%
pd.merge(df_not_remote_jobs, df_not_remote_salary, on = 'job_title_short', how = 'right').head()
# Out:
#     job_title_short                                 job_title  \
# 0  Business Analyst  Technology & Operations Business Analyst
# 1  Business Analyst              Business Intelligence Intern
# 2  Business Analyst                               BI Engineer
# 3  Business Analyst                          Business Analyst
# 4  Business Analyst                        Commercial Analyst
#
#             job_location             job_via job_schedule_type  \
# 0    Copenhagen, Denmark     via Trabajo.org         Full-time
# 1             Dallas, TX        via LinkedIn         Full-time
# 2                Namibia  via Intellijobs.ai         Full-time
# 3  Tel Aviv-Yafo, Israel          via Comeet         Full-time
# 4           South Africa        via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False               Denmark 2023-06-05 13:44:34
# 1               False  Texas, United States 2023-01-04 13:02:07
# ...

# %%
df_company_salary = df.groupby(by = 'company_name')[['salary_year_avg']].mean()

# %%
df_company_salary
# Out:
#                                              salary_year_avg
# company_name
# "Dbank"                                                  NaN
# "Hamkorbank" АТБ                                         NaN
# "KELKOO"                                                 NaN
# "PASHA Holding" LLC                                      NaN
# "TECHNICUS LTD" sp. z o.o. ODDZIAŁ W POLSCE              NaN
# ...                                                      ...
# 𝐏𝐓 𝐌𝐢𝐭𝐫𝐚 𝐏𝐢𝐧𝐚𝐬𝐭𝐡𝐢𝐤𝐚 𝐌𝐮𝐬𝐭𝐢𝐤𝐚 𝐑𝐞𝐧𝐭 (𝐌𝐏𝐌 𝐑𝐞𝐧𝐭)              NaN
# 🇮🇳 easyfix.in                                            NaN
# 🏛️WalletConnect                                          NaN
# 💻 LGA IT                                                 NaN
# 💾Data Trust Associates                                   NaN
#
# [139982 rows x 1 columns]

# %%
df_company_remote = df[df.job_work_from_home == True].groupby(by = 'company_name').size().reset_index(name = 'remote_count')

# %%
df_company_remote
# Out:
#                                     company_name  remote_count
# 0                                    #EqualsTrue             4
# 1                                  #TeamGoHealth             1
# 2                        #twiceasnice Recruiting             1
# 3                                          &Work             1
# 4      (AEG) Application Engineering Group, Inc.             1
# ...                                          ...           ...
# 22983                                       知名外企             1
# 22984                                       精鼎医药             1
# 22985                     英屬維京群島商瑞嘉耐思科技有限公司台灣分公司             1
# 22986                                         雅虎             2
# 22987                                  𝐎𝐩𝐞𝐧𝐬𝐭𝐚𝐟𝐟             1
#
# [22988 rows x 2 columns]

# %%
df_company_remote.set_index('company_name', inplace = True)

# %%
df_company_remote
# Out:
#                                            remote_count
# company_name
# #EqualsTrue                                           4
# #TeamGoHealth                                         1
# #twiceasnice Recruiting                               1
# &Work                                                 1
# (AEG) Application Engineering Group, Inc.             1
# ...                                                 ...
# 知名外企                                                  1
# 精鼎医药                                                  1
# 英屬維京群島商瑞嘉耐思科技有限公司台灣分公司                                1
# 雅虎                                                    2
# 𝐎𝐩𝐞𝐧𝐬𝐭𝐚𝐟𝐟                                             1
#
# [22988 rows x 1 columns]

# %%
pd.merge(df_company_salary, df_company_remote, on='company_name', how='inner').head()
# Out:
#                                            salary_year_avg  remote_count
# company_name
# #EqualsTrue                                            NaN             4
# #TeamGoHealth                                          NaN             1
# #twiceasnice Recruiting                            77750.0             1
# &Work                                                  NaN             1
# (AEG) Application Engineering Group, Inc.              NaN             1

# %% [markdown]
# # concat dataframes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_jan = df[df.job_posted_date.dt.month == 1].copy()

# %%
df_feb = df[df.job_posted_date.dt.month == 2].copy()

# %%
df_jan
# Out:
#              job_title_short                                  job_title  \
# job_index
# 1               Data Analyst                               Data Analyst
# 20            Data Scientist                             Data Scientist
# 39             Data Engineer                              Data Engineer
# 53             Data Engineer                              Data Engineer
# 55            Data Scientist                             Data Scientist
# ...                      ...                                        ...
# 785699     Software Engineer                        Simulation Engineer
# 785700         Data Engineer                       Data Engineer Ssr/Sr
# 785703          Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704      Business Analyst                           Business Analyst
# 785705          Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                     job_location             job_via  \
# job_index
# ...

# %%
pd.concat([df_jan, df_feb]) # index will not change and look bad
# Out:
#                 job_title_short  \
# job_index
# 1                  Data Analyst
# 20               Data Scientist
# 39                Data Engineer
# 53                Data Engineer
# 55               Data Scientist
# ...                         ...
# 784588            Data Engineer
# 784779     Senior Data Engineer
# 784994        Software Engineer
# 785142         Business Analyst
# 785402        Software Engineer
#
#                                                    job_title  \
# job_index
# 1                                               Data Analyst
# 20                                            Data Scientist
# 39                                             Data Engineer
# 53                                             Data Engineer
# 55                                            Data Scientist
# ...                                                      ...
# 784588                                         Data Engineer
# ...

# %%
pd.concat([df_jan, df_feb], ignore_index= True)
# Out:
#              job_title_short  \
# 0               Data Analyst
# 1             Data Scientist
# 2              Data Engineer
# 3              Data Engineer
# 4             Data Scientist
# ...                      ...
# 156395         Data Engineer
# 156396  Senior Data Engineer
# 156397     Software Engineer
# 156398      Business Analyst
# 156399     Software Engineer
#
#                                                 job_title  \
# 0                                            Data Analyst
# 1                                          Data Scientist
# 2                                           Data Engineer
# 3                                           Data Engineer
# 4                                          Data Scientist
# ...                                                   ...
# 156395                                      Data Engineer
# 156396                  Senior Data Engineer - SQL/Python
# 156397                    Microsoft Dynamics CRM Engineer
# ...

# %%
dict_months = {
    'Jan': df_jan,
    'Feb': df_feb,
    'Mar': df_mar,
    'Apr': df_apr,
    'May': df_may,
    'Jun': df_jun,
    'Jul': df_jul,
    'Aug': df_aug,
    'Sep': df_sep,
    'Oct': df_oct,
    'Nov': df_nov,
    'Dec': df_dec
 }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[467], line 4
#       1 dict_months = {
#       2     'Jan': df_jan,
#       3     'Feb': df_feb,
# ----> 4     'Mar': df_mar,
#       5     'Apr': df_apr,
#       6     'May': df_may,
#       7     'Jun': df_jun,
#       8     'Jul': df_jul,
#       9     'Aug': df_aug,
#      10     'Sep': df_sep,
#      11     'Oct': df_oct,
#      12     'Nov': df_nov,
#      13     'Dec': df_dec
#      14  }
#
# NameError: name 'df_mar' is not defined

# %%
months = (
    df.job_posted_date
    .dt.strftime('%b')
    .unique()
)

# %%
months
# Out:
# array(['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr',
#        'Feb', 'Sep', 'May'], dtype=object)

# %%
dict_months = {}
month_df = 'df_'

for month in months:
    print(month)
    dict_months[f"df_{month}"] = df[df.job_posted_date.dt.strftime('%b') == month]
    
    #month_df = 'df_'+ month
    #month_df = df[df.job_posted_date.dt.strftime('%b') == month]
    #dict_months[month] = 'df_'+ month

    # month_df = df[df.job_posted_date.dt.strftime('%b') == month]

    # globals()['df_' + month] = month_df        # Optional: creates df_Jan, df_Feb, etc. as global variables
    # dict_months[month] = month_df
# Out:
# Jun
# Jan
# Oct
# Jul
# Aug
# Nov
# Mar
# Dec
# Apr
# Feb
# Sep
# May

# %%
dict_months['df_Jan']
# Out:
#              job_title_short                                  job_title  \
# job_index
# 1               Data Analyst                               Data Analyst
# 20            Data Scientist                             Data Scientist
# 39             Data Engineer                              Data Engineer
# 53             Data Engineer                              Data Engineer
# 55            Data Scientist                             Data Scientist
# ...                      ...                                        ...
# 785699     Software Engineer                        Simulation Engineer
# 785700         Data Engineer                       Data Engineer Ssr/Sr
# 785703          Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704      Business Analyst                           Business Analyst
# 785705          Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                     job_location             job_via  \
# job_index
# ...

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
data_scientist_df = df[df.job_title_short=='Data Scientist'].copy()

# %%
data_analyst_df = df[df.job_title_short=='Data Analyst'].copy()

# %%
combined_df = pd.concat([data_scientist_df,data_analyst_df], ignore_index=True)

# %%
combined_df
# Out:
#        job_title_short                                          job_title  \
# 0       Data Scientist                                  Data Scientist II
# 1       Data Scientist                             Data Science Team Lead
# 2       Data Scientist                                     Data Scientist
# 3       Data Scientist                                     Data Scientist
# 4       Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 368356    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 368357    Data Analyst          Expert Business Data Analyst - Now Hiring
# 368358    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 368359    Data Analyst                 Data & Analytics Architect (w/m/x)
# 368360    Data Analyst                                   CRM Data Analyst
#
#                       job_location  \
# 0                         Anywhere
# ...

# %%
oct_df = df[df.job_posted_date.dt.strftime('%b')=='Oct'].copy()

# %%
nov_df = df[df.job_posted_date.dt.strftime('%b')=='Nov'].copy()

# %%
dec_df = df[df.job_posted_date.dt.strftime('%b')=='Dec'].copy()

# %%
combined_df = pd.concat([oct_df, nov_df, dec_df], ignore_index = True)

# %%
combined_df
# Out:
#          job_title_short                                          job_title  \
# 0          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 1          Data Engineer                                      Data Engineer
# 2           Data Analyst                                       Data Analyst
# 3           Data Analyst                           Stage - Data Analyst F/H
# 4           Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# ...                  ...                                                ...
# 187359     Data Engineer                                      Data Engineer
# 187360     Data Engineer                                      Data Engineer
# 187361      Data Analyst                                  Data Analyst Lead
# 187362  Business Analyst         Business Analysis and Intelligence Manager
# 187363    Cloud Engineer                             Engineer 3, Facilities
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_schedule_type.value_counts()
# Out:
# job_schedule_type
# Full-time                                701727
# Contractor                                34793
# Internship                                 8742
# Part-time                                  7881
# Full-time and Part-time                    6287
# Full-time and Temp work                    2603
# Full-time and Internship                   2340
# Full-time and Contractor                   2292
# Contractor and Temp work                   2283
# Temp work                                  2169
# Full-time, Part-time, and Internship        264
# Part-time and Internship                    255
# Temp work and Internship                    211
# Full-time, Contractor, and Temp work        194
# Full-time, Temp work, and Internship        173
# Part-time and Contractor                    160
# Full-time, Part-time, and Temp work         131
# Full-time, Part-time, and Contractor        119
# Part-time and Temp work                     111
# ...

# %%
full_time_df = df[df.job_schedule_type == 'Full-time'].copy()

# %%
part_time_df = df[df.job_schedule_type == 'Part-time'].copy()

# %%
combined_df = pd.concat([full_time_df,part_time_df], ignore_index = True)

# %%
combined_df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 709603         Data Engineer
# 709604  Senior Data Engineer
# 709605        Data Scientist
# 709606      Business Analyst
# 709607        Data Scientist
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 709603                                     Data Engineer*
# 709604                               Senior Data Engineer
# 709605     Математик, Junior/Middle/Senior Data Scientist
# ...

# %% [markdown]
# # exporting data

# %%
combined_df.head(5).to_clipboard()

# %% [markdown]
# 	job_title_short	job_title	job_location	job_via	job_schedule_type	job_work_from_home	search_location	job_posted_date	job_no_degree_mention	job_health_insurance	job_country	salary_rate	salary_year_avg	salary_hour_avg	company_name	job_skills	job_type_skills
# 0	Senior Data Engineer	Senior Clinical Data Engineer / Principal Clinical Data Engineer ...	Watertown, CT	via Work Nearby	Full-time	False	Texas, United States	2023-06-16 13:44:15	False	False	United States				Boehringer Ingelheim
# 1	Data Analyst	Data Analyst	Guadalajara, Jalisco, Mexico	via BeBee México	Full-time	False	Mexico	2023-01-14 13:18:07	False	False	Mexico				Hewlett Packard Enterprise	['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']	{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}
# 2	Data Engineer	Data Engineer/Scientist/Analyst, Mid or Senior (m/f/x)	Berlin, Germany	via LinkedIn	Full-time	False	Germany	2023-10-10 13:14:55	False	False	Germany				ALPHA Augmented Services	['python', 'sql', 'c#', 'azure', 'airflow', 'dax', 'docker', 'kubernetes', 'jenkins']	{'analyst_tools': ['dax'], 'cloud': ['azure'], 'libraries': ['airflow'], 'other': ['docker', 'kubernetes', 'jenkins'], 'programming': ['python', 'sql', 'c#']}
# 3	Data Engineer	LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ENGINEER -  DATA...	San Antonio, TX	via Diversity.com	Full-time	False	Texas, United States	2023-07-04 13:01:41	True	False	United States				Southwest Research Institute	['python', 'c++', 'java', 'matlab', 'aws', 'tensorflow', 'keras', 'pytorch']	{'cloud': ['aws'], 'libraries': ['tensorflow', 'keras', 'pytorch'], 'programming': ['python', 'c++', 'java', 'matlab']}
# 4	Data Engineer	Data Engineer- Sr Jobs	Washington, DC	via Clearance Jobs	Full-time	False	Sudan	2023-08-07 14:29:36	False	False	Sudan				Kristina Daniel	['bash', 'python', 'oracle', 'aws', 'ansible', 'puppet', 'jenkins', 'gitlab', 'git']	{'cloud': ['oracle', 'aws'], 'other': ['ansible', 'puppet', 'jenkins', 'gitlab', 'git'], 'programming': ['bash', 'python']}

# %%
combined_df.head(5).to_clipboard(sep = ',') 
# adds comma after each value

# %% [markdown]
# ,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills
# 0,Senior Data Engineer,Senior Clinical Data Engineer / Principal Clinical Data Engineer ...,"Watertown, CT",via Work Nearby,Full-time,False,"Texas, United States",2023-06-16 13:44:15,False,False,United States,,,,Boehringer Ingelheim,,
# 1,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}"
# 2,Data Engineer,"Data Engineer/Scientist/Analyst, Mid or Senior (m/f/x)","Berlin, Germany",via LinkedIn,Full-time,False,Germany,2023-10-10 13:14:55,False,False,Germany,,,,ALPHA Augmented Services,"['python', 'sql', 'c#', 'azure', 'airflow', 'dax', 'docker', 'kubernetes', 'jenkins']","{'analyst_tools': ['dax'], 'cloud': ['azure'], 'libraries': ['airflow'], 'other': ['docker', 'kubernetes', 'jenkins'], 'programming': ['python', 'sql', 'c#']}"
# 3,Data Engineer,LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ENGINEER -  DATA...,"San Antonio, TX",via Diversity.com,Full-time,False,"Texas, United States",2023-07-04 13:01:41,True,False,United States,,,,Southwest Research Institute,"['python', 'c++', 'java', 'matlab', 'aws', 'tensorflow', 'keras', 'pytorch']","{'cloud': ['aws'], 'libraries': ['tensorflow', 'keras', 'pytorch'], 'programming': ['python', 'c++', 'java', 'matlab']}"
# 4,Data Engineer,Data Engineer- Sr Jobs,"Washington, DC",via Clearance Jobs,Full-time,False,Sudan,2023-08-07 14:29:36,False,False,Sudan,,,,Kristina Daniel,"['bash', 'python', 'oracle', 'aws', 'ansible', 'puppet', 'jenkins', 'gitlab', 'git']","{'cloud': ['oracle', 'aws'], 'other': ['ansible', 'puppet', 'jenkins', 'gitlab', 'git'], 'programming': ['bash', 'python']}"

# %%
combined_df.head(5).to_csv('delete_job_details.csv')

# %%
temp_df = pd.read_csv("delete_job_details.csv")

# %%
temp_df
# Out:
#    Unnamed: 0       job_title_short  \
# 0           0  Senior Data Engineer
# 1           1          Data Analyst
# 2           2         Data Engineer
# 3           3         Data Engineer
# 4           4         Data Engineer
#
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# ...

# %%
temp_df = pd.read_csv("delete_job_details.csv", index_col= 0) #treats first column as index otherwise it creates it own

# %%
temp_df
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
temp_df.to_excel("delete_job_details.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[538], line 1
# ----> 1 temp_df.to_excel("delete_job_details.xlsx")
#
# File /opt/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
conda install openpyxl
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/python_course
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     et_xmlfile-1.1.0           |  py311hca03da5_0          12 KB
#     openpyxl-3.1.5             |  py311h80987f9_0         702 KB
#     ------------------------------------------------------------
#                                            Total:         714 KB
#
# The following NEW packages will be INSTALLED:
#
#   et_xmlfile         pkgs/main/osx-arm64::et_xmlfile-1.1.0-py311hca03da5_0
#   openpyxl           pkgs/main/osx-arm64::openpyxl-3.1.5-py311h80987f9_0
#
#
#
# ...
# openpyxl-3.1.5       | 702 KB    |                                       |   0%
# ...

# %%
temp_df.to_excel("delete_job_details.xlsx")

# %%
conda install sqlalchemy
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/python_course
#
#   added / updated specs:
#     - sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     greenlet-3.1.1             |  py311h313beb8_0         239 KB
#     sqlalchemy-2.0.39          |  py311hbe2cdee_0         6.6 MB
#     ------------------------------------------------------------
#                                            Total:         6.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   greenlet           pkgs/main/osx-arm64::greenlet-3.1.1-py311h313beb8_0
#   sqlalchemy         pkgs/main/osx-arm64::sqlalchemy-2.0.39-py311hbe2cdee_0
#
#
#
# ...
# sqlalchemy-2.0.39    | 6.6 MB    |                                       |   0%
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///jobs.db')

# %%
df.to_sql('job_table', con=engine, if_exists='append', index=False)
# Out:
# 785741

# %%
df
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
(
    df.head(5)
    .to_csv('data_jobs_export.csv', index=False)
)

# %%
df[df.job_title_short=='Data Scientist'].to_csv('data_scientist_jobs.csv', index=False)

# %%
df[df.job_location=='New York, NY'].to_excel('new_york_jobs.xlsx', index=False)

# %% [markdown]
# # applying functions

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df[df.salary_year_avg.notna()].salary_year_avg
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month.value_counts().sort_index()
# Out:
# job_posted_date
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func: 'AggFuncType', axis: 'Axis' = 0, raw: 'bool' = False, result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None, args=(), by_row: "Literal[False, 'compat']" = 'compat', engine: "Literal['python', 'numba']" = 'python', engine_kwargs: 'dict[str, bool] | None' = None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
def projected_sal(salary):
    return salary*1.03

df[df.salary_year_avg.notna()].salary_year_avg.apply(projected_sal)
# Out:
# 28        112785.00
# 77        144200.00
# 92        123600.00
# 100       235068.66
# 109        91670.00
#             ...
# 785624    143392.48
# 785641    154500.00
# 785648    228531.25
# 785682    162225.00
# 785692    162225.00
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df['salary_year_inflated'] = df.salary_hour_avg.apply(projected_sal)

# %%
df[['salary_year_avg','salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
# ...                 ...                   ...
# 785736              NaN                   NaN
# 785737              NaN                   NaN
# 785738              NaN                   NaN
# 785739              NaN                   NaN
# 785740              NaN                   NaN
#
# [785741 rows x 2 columns]

# %%
df['salary_year_inflated'] = df.salary_hour_avg.apply(lambda x: x*1.03)

# %%
df[['salary_year_avg','salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
# ...                 ...                   ...
# 785736              NaN                   NaN
# 785737              NaN                   NaN
# 785738              NaN                   NaN
# 785739              NaN                   NaN
# 785740              NaN                   NaN
#
# [785741 rows x 2 columns]

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_practice = df.copy()

# %%
df_practice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
list(df_practice.job_skills.head())
# Out:
# [None,
#  "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']",
#  "['python', 'sql', 'c#', 'azure', 'airflow', 'dax', 'docker', 'kubernetes', 'jenkins']",
#  "['python', 'c++', 'java', 'matlab', 'aws', 'tensorflow', 'keras', 'pytorch']",
#  "['bash', 'python', 'oracle', 'aws', 'ansible', 'puppet', 'jenkins', 'gitlab', 'git']"]

# %%
df_practice.job_skills.to_list()
# Out:
# [None,
#  "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']",
#  "['python', 'sql', 'c#', 'azure', 'airflow', 'dax', 'docker', 'kubernetes', 'jenkins']",
#  "['python', 'c++', 'java', 'matlab', 'aws', 'tensorflow', 'keras', 'pytorch']",
#  "['bash', 'python', 'oracle', 'aws', 'ansible', 'puppet', 'jenkins', 'gitlab', 'git']",
#  "['python', 'sql', 'gcp']",
#  "['sql', 'python', 'java', 'sql server', 'gcp', 'bigquery', 'hadoop']",
#  "['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigquery', 'databricks', 'redshift', 'airflow', 'kafka', 'spark']",
#  "['excel', 'powerpoint', 'power bi']",
#  "['sql', 'python', 'r', 'mongodb', 'mongodb', 'sql server', 'azure', 'pandas', 'spark', 'windows', 'excel']",
#  "['python', 'databricks', 'azure', 'spark']",
#  "['python', 'qlik']",
#  "['sql', 'php', 'excel', 'power bi', 'sap', 'jira']",
#  "['python', 'sql', 'go', 'ruby', 'ruby', 'javascript', 'aws', 'flask', 'fastapi', 'terraform']",
#  "['mongodb', 'mongodb']",
# ...

# %%
import ast

# %%
ast.literal_eval(df_practice['job_skills'][1])
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
    # if skill_list.notna():
        return ast.literal_eval(skill_list)

# %%
df_practice['job_skills'] = df_practice.job_skills.apply(clean_list)

# %%
df_practice['job_skills_1'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_practice.iloc[1]
# Out:
# job_title_short                                               Data Analyst
# job_title                                                     Data Analyst
# job_location                                  Guadalajara, Jalisco, Mexico
# job_via                                                   via BeBee México
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Mexico
# job_posted_date                                        2023-01-14 13:18:07
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                         Mexico
# salary_rate                                                           None
# ...

# %%
def projected_sal(row):
    if "senior" in row.job_title_short.lower():
        return row.salary_year_avg * 1.10
    else:
        return row.salary_year_avg * 1.03

# %%
df_practice.job_title_short.head().lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9m/z34hzp3d30q874n20_86hvdm0000gn/T/ipykernel_45544/3873833931.py in ?()
# ----> 1 df_practice.job_title_short.head().lower()
#
# /opt/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
df_practice['salary_year_inflated'] = df_practice.apply(projected_sal, axis = 1)

# %%
df_practice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_practice[df.salary_year_avg.notna()][['job_title_short', 'salary_year_avg', 'salary_year_inflated']].sample(10)
# Out:
#               job_title_short  salary_year_avg  salary_year_inflated
# 161494   Senior Data Engineer         181500.0              199650.0
# 340549           Data Analyst         115000.0              115000.0
# 546794  Senior Data Scientist          72000.0               79200.0
# 345103           Data Analyst          45000.0               45000.0
# 521641         Data Scientist         151782.0              151782.0
# 495659         Data Scientist          90000.0               90000.0
# 613407  Senior Data Scientist         129833.0              142816.3
# 126348          Data Engineer         163782.0              163782.0
# 655561   Senior Data Engineer          90000.0               99000.0
# 421252          Data Engineer         135000.0              135000.0

# %%
df_practice = df.copy()

# %%
df_practice['job_posted_date'] = df_practice.job_posted_date.apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
df_practice['job_posted_date']
# Out:
# 0         2023-06-16
# 1         2023-01-14
# 2         2023-10-10
# 3         2023-07-04
# 4         2023-08-07
#              ...
# 785736    2023-03-13
# 785737    2023-03-12
# 785738    2023-03-12
# 785739    2023-03-12
# 785740    2023-03-13
# Name: job_posted_date, Length: 785741, dtype: object

# %%
from datetime import datetime as dt

# %%
dt.now()
# Out:
# datetime.datetime(2025, 7, 3, 16, 2, 11, 98350)

# %%
now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
#   Cell In[679], line 1
#     now().strftime('%Y-%m-%d %H:%M:%S'))
#                                        ^
# SyntaxError: unmatched ')'

# %%
(dt.now() - pd.to_datetime(df_practice['job_posted_date'][1])).days
# Out:
# 901

# %%
df_practice['days_since_posted'] = df_practice.job_posted_date.apply(lambda x: (dt.now() - pd.to_datetime(x)).days)

# %%
df_practice[['job_posted_date','days_since_posted']]
# Out:
#        job_posted_date  days_since_posted
# 0           2023-06-16                748
# 1           2023-01-14                901
# 2           2023-10-10                632
# 3           2023-07-04                730
# 4           2023-08-07                696
# ...                ...                ...
# 785736      2023-03-13                843
# 785737      2023-03-12                844
# 785738      2023-03-12                844
# 785739      2023-03-12                844
# 785740      2023-03-13                843
#
# [785741 rows x 2 columns]

# %%
df_filtered = df[df.salary_year_avg.notna()].copy()

# %%
def sal_category(sal):
    if sal < 60_000:
        category = 'Low'
    elif sal <= 100_000:
        category = 'Medium'
    elif sal > 100_000:
        category = 'High'

    return category

# %%
df_filtered
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df_filtered['salary_category'] = df_filtered['salary_year_avg'].apply(sal_category)

# %%
df_filtered['salary_category'] = df_filtered['salary_year_avg'].apply(lambda sal: 'Low' if sal < 60_000 else 'Medium' if sal <=100_000 else 'High')

# %%
df_filtered.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# # explode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_practice = df.copy()

# %%
# convert string column to list

df_practice['job_skills'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
(
df_practice.job_skills
 .explode()
 .value_counts()
 .head(10)
 .plot(kind = 'bar')
)
# Out:
# <Axes: xlabel='job_skills'>

# %%
df_practice[['job_title_short','job_skills']].explode('job_skills')
# Out:
#              job_title_short  job_skills
# 0       Senior Data Engineer        None
# 1               Data Analyst           r
# 1               Data Analyst      python
# 1               Data Analyst         sql
# 1               Data Analyst       nosql
# ...                      ...         ...
# 785739         Data Engineer       kafka
# 785739         Data Engineer  kubernetes
# 785739         Data Engineer      docker
# 785740     Software Engineer         aws
# 785740     Software Engineer        flow
#
# [3777320 rows x 2 columns]

# %%
df_exploded = df_practice.explode('job_skills')

# %%
df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded.groupby(by = ['job_title_short', 'job_skills']).size()
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
df_skilled = df_exploded.groupby(by = ['job_title_short', 'job_skills']).size().reset_index(name = 'skill_count')

# %%
df_skilled.sort_values('skill_count', ascending=False)
# Out:
#             job_title_short   job_skills  skill_count
# 1066         Data Scientist       python       113711
# 865           Data Engineer          sql       113130
# 830           Data Engineer       python       108022
# 625            Data Analyst          sql        92428
# 1101         Data Scientist          sql        78982
# ...                     ...          ...          ...
# 266          Cloud Engineer       delphi            1
# 1920  Senior Data Scientist  objective-c            1
# 1400    Senior Data Analyst      couchdb            1
# 298          Cloud Engineer      haskell            1
# 631            Data Analyst         suse            1
#
# [2256 rows x 3 columns]

# %%
job_title = 'Data Analyst'
skill_count = 10

df_skilled[df_skilled.job_title_short==job_title].sort_values('skill_count', ascending=False).head(skill_count).plot('job_skills','skill_count', kind = 'bar', color = 'blue')
plt.gca().invert_xaxis()
plt.title(f"Top {skill_count} skills for {job_title}")
plt.legend().set_visible(False)
plt.show()

# %%
job_title = 'Data Scientist'
skill_count = 10

df_skilled[df_skilled.job_title_short==job_title].sort_values('skill_count', ascending=False).head(skill_count).plot('job_skills','skill_count', kind = 'bar', color = 'green')
plt.gca().invert_xaxis()
plt.title(f"Top {skill_count} skills for {job_title}")
plt.legend().set_visible(False)
plt.show()

# %%
job_title = 'Data Engineer'
skill_count = 10

df_skilled[df_skilled.job_title_short==job_title].sort_values('skill_count', ascending=False).head(skill_count).plot('job_skills','skill_count', kind = 'bar', color = 'red')
plt.gca().invert_xaxis()
plt.title(f"Top {skill_count} skills for {job_title}")
plt.legend().set_visible(False)
plt.show()

# %%
df_exploded.groupby(by = ['job_skills', 'job_title_short']).size()
# Out:
# job_skills  job_title_short
# airflow     Business Analyst               318
#             Cloud Engineer                 260
#             Data Analyst                  2002
#             Data Engineer                25505
#             Data Scientist                3915
#                                          ...
# zoom        Machine Learning Engineer       46
#             Senior Data Analyst             86
#             Senior Data Engineer           122
#             Senior Data Scientist           79
#             Software Engineer              229
# Length: 2256, dtype: int64

# %%
df_exploded.pivot_table(index = 'job_title_short', columns = 'job_skills', aggfunc= 'size')
# Out:
# job_skills                 airflow  airtable  alteryx  angular  angular.js  \
# job_title_short
# Business Analyst             318.0      17.0   1078.0     87.0         NaN
# Cloud Engineer               260.0       2.0     28.0    138.0         6.0
# Data Analyst                2002.0      88.0   4570.0    376.0         2.0
# Data Engineer              25505.0      68.0   2294.0   1446.0        45.0
# Data Scientist              3915.0      65.0   2068.0    736.0        12.0
# Machine Learning Engineer   1164.0       5.0     61.0     92.0         1.0
# Senior Data Analyst          596.0      10.0   1186.0     54.0         NaN
# Senior Data Engineer        8694.0      20.0    467.0    303.0        19.0
# Senior Data Scientist       1403.0      10.0    430.0    101.0         NaN
# Software Engineer           1397.0      11.0    115.0   2021.0        30.0
#
# job_skills                 ansible    apl  arch  asana  asp.net  ...  wimi  \
# ...

# %%
# top 5 skills for Data Analysts per month

import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df_practice = df.copy()

# %%
df_practice['job_posted_date'] = pd.to_datetime(df_practice.job_posted_date)

# %%
df_practice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df_practice['job_skills'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# df_practice['job_posted_month'] = df_practice.job_posted_date.dt.strftime('%b')

df_practice['job_posted_month'] = df_practice.job_posted_date.dt.month

# %%
df_exploded = df_practice[['job_title_short','job_posted_month','job_skills']].explode('job_skills')

# %%
df_exploded
# Out:
#              job_title_short  job_posted_month  job_skills
# 0       Senior Data Engineer                 6        None
# 1               Data Analyst                 1           r
# 1               Data Analyst                 1      python
# 1               Data Analyst                 1         sql
# 1               Data Analyst                 1       nosql
# ...                      ...               ...         ...
# 785739         Data Engineer                 3       kafka
# 785739         Data Engineer                 3  kubernetes
# 785739         Data Engineer                 3      docker
# 785740     Software Engineer                 3         aws
# 785740     Software Engineer                 3        flow
#
# [3777320 rows x 3 columns]

# %%
df_skills_trended = df_exploded.groupby(by = ['job_title_short', 'job_posted_month', 'job_skills']).size().reset_index(name = 'skill_count')

# %%
df_skills_trended
# Out:
#          job_title_short  job_posted_month job_skills  skill_count
# 0       Business Analyst                 1    airflow           18
# 1       Business Analyst                 1   airtable            1
# 2       Business Analyst                 1    alteryx          106
# 3       Business Analyst                 1    angular           11
# 4       Business Analyst                 1    ansible           14
# ...                  ...               ...        ...          ...
# 22138  Software Engineer                12  workfront            1
# 22139  Software Engineer                12        wsl            3
# 22140  Software Engineer                12    xamarin            2
# 22141  Software Engineer                12       yarn            5
# 22142  Software Engineer                12       zoom           22
#
# [22143 rows x 4 columns]

# %%
df_skills_pivot = df_exploded.pivot_table(index = 'job_posted_month', columns = ['job_title_short','job_skills'], aggfunc='size', fill_value=0)

# %%
df_skills_pivot
# Out:
# job_title_short  Business Analyst                                            \
# job_skills                airflow airtable alteryx angular ansible apl arch
# job_posted_month
# 1                              18        1     106      11      14   0    1
# 2                              25        3      98       6       7   0    0
# 3                              18        1      83       3      20   0    0
# 4                              24        2     114       4       5   0    1
# 5                              27        0      71       4       2   0    1
# 6                              25        1      92       5       5   0    1
# 7                              32        2      72       8      16   1    0
# 8                              34        0     103      12      15   0    1
# 9                              23        1      91       5      16   0    3
# 10                             37        2      96       6       6   1    5
# ...

# %%
# retreive top 5 skills for Data Analyst
job_title = 'Data Analyst'
skill_count = 5

df_skills_pivot.loc[:,job_title].sum().sort_values(ascending = False).head(skill_count)
top_skills = df_skills_pivot.loc[:,job_title].sum().sort_values(ascending = False).head(skill_count).index

# %%
top_skills
# Out:
# Index(['sql', 'excel', 'python', 'tableau', 'power bi'], dtype='object', name='job_skills')

# %%
df_skills_pivot.loc[:,(job_title,top_skills)].plot()
plt.title(f"Top {skill_count} skills for {job_title}")
plt.legend(top_skills)

# %%
job_title = 'Data Analyst'
skill_count = 10

df_skills_trended[df_skills_trended.job_title_short==job_title].sort_values(by = 'skill_count', ascending=False).plot('job_posted_month', 'skill_count', kind = 'line', legend = 'job_skills')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
#if you want to do it for any role:

df_practice = df.copy()
df_practice['job_posted_date'] = pd.to_datetime(df_practice.job_posted_date)
df_practice['job_posted_month'] = df_practice.job_posted_date.dt.month

#convert string to list
df_practice['job_skills'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

#explode the list and create a pivot
df_exploded = df_practice[['job_title_short','job_posted_month','job_skills']].explode('job_skills')
df_skills_pivot = df_exploded.pivot_table(index = 'job_posted_month', columns = ['job_title_short','job_skills'], aggfunc='size', fill_value=0)

# retrieve top 5 skills for Data Analyst
job_title = 'Data Scientist'
skill_count = 5
top_skills = df_skills_pivot.loc[:,job_title].sum().sort_values(ascending = False).head(skill_count).index

#plot chart
df_skills_pivot.loc[:,(job_title,top_skills)].plot()
plt.title(f"Top {skill_count} skills for {job_title}")
plt.legend(top_skills)
plt.show()

# %%
#if you want to do it for any role:

df_practice = df.copy()
df_practice['job_posted_date'] = pd.to_datetime(df_practice.job_posted_date)
df_practice['job_posted_month'] = df_practice.job_posted_date.dt.month

#convert string to list
df_practice['job_skills'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

#explode the list and create a pivot
df_exploded = df_practice[['job_title_short','job_posted_month','job_skills']].explode('job_skills')
df_skills_pivot = df_exploded.pivot_table(index = 'job_posted_month', columns = ['job_title_short','job_skills'], aggfunc='size', fill_value=0)

# retrieve top 5 skills for Data Analyst
job_title = 'Data Analyst'
skill_count = 5
top_skills = df_skills_pivot.loc[:,job_title].sum().sort_values(ascending = False).head(skill_count).index

#plot chart
df_skills_pivot.loc[:,(job_title,top_skills)].plot()
plt.title(f"Top {skill_count} skills for {job_title}")
plt.legend(top_skills)
plt.show()

# %%
# retrieve top 5 skills for Data Analyst
job_title = 'Cloud Engineer'
skill_count = 10
top_skills = df_skills_pivot.loc[:,job_title].sum().sort_values(ascending = False).head(skill_count).index

# #plot chart
# df_skills_pivot.loc[:,(job_title,top_skills)].plot()
# plt.title(f"Top {skill_count} skills for {job_title}")
# plt.legend(top_skills)
# plt.show()

# %%
df_skills_pivot
# Out:
# job_title_short  Business Analyst                                            \
# job_skills                airflow airtable alteryx angular ansible apl arch
# job_posted_month
# 1                              18        1     106      11      14   0    1
# 2                              25        3      98       6       7   0    0
# 3                              18        1      83       3      20   0    0
# 4                              24        2     114       4       5   0    1
# 5                              27        0      71       4       2   0    1
# 6                              25        1      92       5       5   0    1
# 7                              32        2      72       8      16   1    0
# 8                              34        0     103      12      15   0    1
# 9                              23        1      91       5      16   0    3
# 10                             37        2      96       6       6   1    5
# ...

# %%
df_skills_pivot[df_skills_pivot.job_title_short =='Cloud Engineer'].loc[:,(job_title,top_skills)].sum().plot(x=top_skills, kind = 'bar')
plt.xlabel('Skills')
plt.ylabel('Count')
plt.title(f'Top {skill_count} Most Common Skills for {job_title}')
plt.legend(top_skills)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9m/z34hzp3d30q874n20_86hvdm0000gn/T/ipykernel_45544/4063568103.py in ?()
# ----> 1 df_skills_pivot[df_skills_pivot.job_title_short =='Cloud Engineer'].loc[:,(job_title,top_skills)].sum().plot(x=top_skills, kind = 'bar')
#       2 plt.xlabel('Skills')
#       3 plt.ylabel('Count')
#       4 plt.title(f'Top {skill_count} Most Common Skills for {job_title}')
#
# /opt/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'job_title_short'

# %%
df_skills_pivot
# Out:
# job_title_short  Business Analyst                                            \
# job_skills                airflow airtable alteryx angular ansible apl arch
# job_posted_month
# 1                              18        1     106      11      14   0    1
# 2                              25        3      98       6       7   0    0
# 3                              18        1      83       3      20   0    0
# 4                              24        2     114       4       5   0    1
# 5                              27        0      71       4       2   0    1
# 6                              25        1      92       5       5   0    1
# 7                              32        2      72       8      16   1    0
# 8                              34        0     103      12      15   0    1
# 9                              23        1      91       5      16   0    3
# 10                             37        2      96       6       6   1    5
# ...

# %%
#if you want to do it for any role:

df_practice = df.copy()
df_practice['job_posted_date'] = pd.to_datetime(df_practice.job_posted_date)
df_practice['job_posted_month'] = df_practice.job_posted_date.dt.month

#convert string to list
df_practice['job_skills'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_practice[['job_skills','salary_year_avg']].explode('job_skills').groupby('job_skills')['salary_year_avg'].mean().sort_values(ascending=False).head(5)
# Out:
# job_skills
# debian         196500.000000
# ringcentral    182500.000000
# lua            170500.000000
# mongo          169526.929749
# dplyr          160667.210526
# Name: salary_year_avg, dtype: float64

# %%
df_practice = df.copy()
df_practice['job_posted_date'] = pd.to_datetime(df_practice.job_posted_date)
df_practice['job_posted_month'] = df_practice.job_posted_date.dt.month

# %%
df_practice['job_skills'] = df_practice.job_skills.apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_practice[['job_title_short', 'job_skills']].explode('job_skills').groupby('job_title_short')['job_skills'].nunique().reset_index(name = 'num_unique_skills')
# Out:
#              job_title_short  num_unique_skills
# 0           Business Analyst                223
# 1             Cloud Engineer                213
# 2               Data Analyst                235
# 3              Data Engineer                239
# 4             Data Scientist                237
# 5  Machine Learning Engineer                222
# 6        Senior Data Analyst                207
# 7       Senior Data Engineer                226
# 8      Senior Data Scientist                215
# 9          Software Engineer                239
